# %%
import pandas as pd

#sample data load
df = pd.read_csv('./data/sample_data_100.csv', dtype=str)

# %%
# 1) Data preparation
from collections import defaultdict
import re

def _general_preprocessing(df):
    
    # window user_encoding
    df['value_source_value'] = df['value_source_value'].str.encode('utf8', errors = 'strict').str.decode('utf8', errors = 'strict')
    
    # lower, strip space, \d\+ restore
    df['value_source_value'] = df['value_source_value'].str.lower()
    df['value_source_value'] = df['value_source_value'].str.strip()
    df['value_source_value'] = df['value_source_value'].str.replace(r'(\d)(\+)', lambda x: x.groups()[1]*int(x.groups()[0]))
    df['value_source_value'] = df['value_source_value'].str.replace(r'(\d+)(\s+)(\++)', lambda x: x.groups()[2])
    df['value_source_value'] = df['value_source_value'].str.replace(r'(\++)(\d+)(\s+)', lambda x: x.groups()[0])
    
    #replace + to Rh+ only for 'HJ1UHH1'(Rh type laboratory code) 
    _rh_pos_df = df[df['measurement_concept_id'] == 'BL7002']['value_source_value'].str.replace('+','rh+')
    _rh_neg_df = df[df['measurement_concept_id'] == 'BL7002']['value_source_value'].str.replace('-','rh-')
    df.loc[df.measurement_concept_id == 'HJ1UHH1', 'value_source_value'] = _rh_pos_df 
    df.loc[df.measurement_concept_id == 'HJ1UHH1', 'value_source_value'] = _rh_neg_df
    return df

df_with_freq = df.groupby(df.columns.tolist()).size().reset_index(name = 'Freq')
df_with_freq_sort = df_with_freq.sort_values(by = 'Freq',ascending = False)
df_cleaned = _general_preprocessing(df_with_freq_sort)
df_cleaned_regrouped = df_cleaned.groupby(['measurement_concept_id','value_source_value'])
df_cleaned_sort = df_cleaned_regrouped.sum().reset_index().sort_values(by = 'Freq', ascending = False)

dist_dicts = defaultdict(dict)

for cid, value, freq in df_cleaned_sort.values:
    dist_dicts[cid][value] = freq
    
dist_dicts = dict(dist_dicts)
dist_dicts
# Out:
# {'084QQV7': {'negative': 8},
#  '0B2KNQM': {'+': 820,
#   '++': 581,
#   '+++': 442,
#   '5    tr': 1779,
#   '5  tr': 436,
#   'neg   -': 7,
#   'neg  -': 38872,
#   'neg -': 15},
#  '108C2ET': {'negative': 12, 'positive': 1},
#  '13BS45Q': {'negative': 2},
#  '14XUNZH': {'negative': 5},
#  '15PPFC1': {'negative': 7},
#  '17EKPPY': {'negative': 221,
#   'po 1.0': 1,
#   'po 1.1': 1,
#   'po 1.2': 2,
#   'po 1.3': 1,
#   'po 1.4': 1,
#   'po 1.5': 1,
#   'po 1.6': 1,
#   'po 1.7': 1,
#   'positive': 68},
#  '19H2JR3': {'negative': 19},
#  '1COB2TW': {'negative': 2},
#  '1CVG1YB': {'negative': 9},
#  '1F3PZU8': {'negative': 6},
#  '1GRMTL1': {'negative': 84, 'positive': 1},
#  '1HC7DTO': {'neg(1:80)': 1, 'negative': 49},
#  '1UQ6NN1': {'negative': 11},
#  '1UV5TB7': {'negative': 7},
#  '1UZD2W1': {'negative': 9},
#  '2HHM1K5': {'negative': 19},
#  '2LTDWRD': {'negative': 9},
#  '2O2XZC4': {'negative': 1},
#  '2VZHP28': {'negative': 9},
#  '3143J86': {'negative': 281},
#  '329NUGA': {'0.00(0)': 1, '0.01(0)': 2, '0.02(0)': 1, '<0.35(0)': 2},
#  '3FLVWUC': {'<0.35(0)': 2},
#  '3GVY49N': {'negative': 23},
#  '3H1249I': {'negative': 7},
#  '3LIUXBT': {'negative': 1},
#  '3R829QQ': {'bm°á°úâüá¶': 8, '°ñ¼öæçµ¶°á°ú âüá¶': 6},
#  '43PQ6PT': {'negative': 8, 'positive': 1},
#  '4A1LQ0M': {'negative': 19},
#  '4AAQHZB': {'negative': 7},
#  '4GCC6RT': {'negative': 15777,
#   'pos(11.00)': 105,
#   'pos(6.0)': 1,
#   'pos(6.1)': 1,
#   'pos(6.2)': 1,
#   'pos(6.3)': 1,
#   'pos(6.4)': 1,
#   'pos(6.5)': 1,
#   'pos(6.6)': 2,
#   'pos(6.7)': 1,
#   'pos(6.8)': 1,
#   'pos(6.9)': 2,
#   'pos(7.0)': 2,
#   'pos(7.1)': 2,
#   'pos(7.2)': 2,
#   'pos(7.3)': 1,
#   'pos(7.4)': 1,
#   'pos(7.5)': 1,
#   'pos(7.6)': 1,
#   'pos(7.7)': 1,
#   'pos(7.8)': 1,
#   'pos(7.9)': 1,
#   'pos(8.0)': 1},
#  '56T78EV': {'negative': 19},
#  '5CJIL4T': {'negative': 187, 'positive': 8},
#  '5G8VSHI': {'negative': 13},
#  '5J4GHT3': {'negative': 9},
#  '5OFXZTQ': {'negative': 19},
#  '5R87RUY': {'negative': 72,
#   'po 1.1': 1,
#   'po 1.2': 1,
#   'po 1.3': 1,
#   'po 1.4': 1,
#   'po 1.5': 1,
#   'po 1.6': 1,
#   'po 1.7': 1,
#   'po 1.8': 1,
#   'po 1.9': 1,
#   'po 2.0': 1,
#   'po 2.3': 1,
#   'po 2.4': 1,
#   'positive': 3},
#  '5Z8JLDM': {'negative': 4, 'pos(4)': 1},
#  '655D8FS': {'negative': 9},
#  '665L3XE': {'negative': 3},
#  '68UASY8': {'negative': 9},
#  '6BZO7H0': {'negative': 6},
#  '6G9MCZR': {'negative': 14, 'pos(3)': 1, 'pos(4)': 2},
#  '6HMFKAC': {'negative': 19},
#  '6LKZ3DS': {'negative': 9},
#  '6NBIOBE': {'neg': 5, 'negative': 48, 'positive': 5},
#  '6S9TBLO': {'negative': 13, 'pos(3)': 1, 'pos(4)': 2},
#  '6VFK8L5': {'negative': 59, 'positive': 1},
#  '6VFSFJY': {'+': 22,
#   '++': 29,
#   '+++': 20,
#   '5    tr': 31,
#   'neg': 3,
#   'neg   -': 1,
#   'neg  -': 614,
#   'neg -': 9},
#  '6YPLFA9': {'negative': 487, 'positive': 2},
#  '70UPL96': {'negative': 6},
#  '77YOR9F': {'neg': 7},
#  '7DEEEBX': {'negative': 1},
#  '7DKUWEM': {'negative': 1},
#  '7HTHG0I': {'+': 1938,
#   '++': 1494,
#   '+++': 953,
#   '25   tr': 3184,
#   '25  tr': 503,
#   '25 tr': 1,
#   'neg   -': 4,
#   'neg  -': 34862,
#   'neg -': 11},
#  '7J8IUQY': {'neg': 70, 'negative': 543},
#  '7M5JQFU': {'negative': 7},
#  '7NRHQ36': {'bm°á°úâüá¶': 5, '°ñ¼öæçµ¶°á°ú âüá¶': 6},
#  '7QHP1DF': {'negative': 14},
#  '7RGI9UY': {'negative': 1, 'positive': 2},
#  '7U5PUNU': {'negative': 9},
#  '7X5ROZZ': {'negative': 19},
#  '81199C1': {'negative': 9},
#  '834SLP4': {'negative': 23},
#  '8H0B2J5': {'negative': 3},
#  '8OXOT6Q': {'negative': 6, 'positive': 35},
#  '8SRVXD2': {'negative': 9},
#  '8VO2KRW': {'equivocal': 13, 'negative': 6, 'positive': 48},
#  '90O5KDH': {'<0.35(0)': 1},
#  '91BHCEA': {'+': 66,
#   '++': 9,
#   '+++': 7,
#   'neg': 3,
#   'neg   -': 1,
#   'neg  -': 637,
#   'neg -': 10},
#  '980RQYI': {'negative': 2, 'positive': 1},
#  '9U260RW': {'0.01(neg)': 5,
#   '0.02(neg)': 23,
#   '0.03(neg)': 21,
#   '0.04(neg)': 16,
#   '0.05(neg)': 8,
#   '0.06(neg)': 4,
#   '0.07(neg)': 2,
#   '0.08(neg)': 1,
#   '0.09(neg)': 1,
#   '0.10(neg)': 1,
#   '0.11(neg)': 1,
#   'borderline': 3,
#   'negative': 156,
#   'positive': 13},
#  '9Z0FOYJ': {'negative': 9},
#  'A1X8CWW': {'negative': 7},
#  'A4K5XQW': {'+': 4106,
#   '++': 2516,
#   '+++': 1643,
#   'neg   -': 5,
#   'neg  -': 34664,
#   'neg -': 14},
#  'A835FOH': {'negative': 55, 'positive': 4},
#  'A9CO6ON': {'negative': 22, 'positive': 1},
#  'AIJCACA': {'ne 0.1': 27,
#   'ne 0.2': 1,
#   'ne 0.3': 1,
#   'ne 0.4': 1,
#   'ne 0.5': 151,
#   'ne 0.6': 5,
#   'ne 0.7': 5,
#   'ne 0.8': 4,
#   'ne 0.9': 4,
#   'ne 1.0': 36,
#   'ne 1.1': 5,
#   'ne 1.2': 4,
#   'ne 1.3': 4,
#   'ne 1.4': 3,
#   'ne 1.5': 4,
#   'ne 1.6': 4,
#   'ne 1.7': 4,
#   'ne 1.8': 3,
#   'ne 1.9': 4,
#   'ne 10.0': 5,
#   'ne 2.0': 4,
#   'ne 2.1': 4,
#   'ne 2.2': 4,
#   'ne 2.3': 4,
#   'ne 2.4': 4,
#   'ne 2.5': 5,
#   'ne 2.6': 5,
#   'ne 2.7': 8,
#   'ne 2.8': 10,
#   'ne 2.9': 12,
#   'ne 3.0': 17,
#   'ne 3.1': 21,
#   'ne 3.2': 22,
#   'ne 3.3': 19,
#   'ne 3.4': 15,
#   'ne 3.5': 13,
#   'ne 3.6': 11,
#   'ne 3.7': 9,
#   'ne 3.8': 8,
#   'ne 3.9': 8,
#   'ne 4.0': 8,
#   'ne 4.1': 7,
#   'ne 4.2': 7,
#   'ne 4.3': 6,
#   'ne 4.4': 5,
#   'ne 4.5': 6,
#   'ne 4.6': 5,
#   'ne 4.7': 5,
#   'ne 4.8': 5,
#   'ne 4.9': 5,
#   'ne 5.0': 4,
#   'ne 5.1': 4,
#   'ne 5.2': 4,
#   'ne 5.3': 4,
#   'ne 5.4': 4,
#   'ne 5.5': 4,
#   'ne 5.6': 3,
#   'ne 5.7': 3,
#   'ne 5.8': 4,
#   'ne 5.9': 3,
#   'ne 6.0': 3,
#   'ne 6.1': 3,
#   'ne 6.2': 3,
#   'ne 6.3': 3,
#   'ne 6.4': 3,
#   'ne 6.5': 2,
#   'ne 6.6': 3,
#   'ne 6.7': 3,
#   'ne 6.8': 3,
#   'ne 6.9': 3,
#   'ne 7.0': 3,
#   'ne 7.1': 2,
#   'ne 7.2': 2,
#   'ne 7.3': 2,
#   'ne 7.4': 2,
#   'ne 7.5': 2,
#   'ne 7.6': 2,
#   'ne 7.7': 2,
#   'ne 7.8': 2,
#   'ne 7.9': 2,
#   'ne 8.0': 2,
#   'ne 8.1': 2,
#   'ne 8.2': 2,
#   'ne 8.3': 2,
#   'ne 8.4': 2,
#   'ne 8.5': 2,
#   'ne 8.6': 2,
#   'ne 8.7': 2,
#   'ne 8.8': 2,
#   'ne 8.9': 2,
#   'ne 9.0': 2,
#   'ne 9.1': 2,
#   'ne 9.2': 2,
#   'ne 9.3': 2,
#   'ne 9.4': 2,
#   'ne 9.5': 2,
#   'ne 9.6': 2,
#   'ne 9.7': 2,
#   'ne 9.8': 2,
#   'ne 9.9': 2,
#   'negative': 1424,
#   'po 1.0': 12,
#   'po 1.1': 25,
#   'po 1.2': 29,
#   'po 1.3': 27,
#   'po 1.4': 27,
#   'po 1.5': 26,
#   'po 1.6': 24,
#   'po 1.7': 23,
#   'po 1.8': 22,
#   'po 1.9': 20,
#   'po 10.0': 4,
#   'po 10.1': 8,
#   'po 10.2': 8,
#   'po 10.3': 8,
#   'po 10.4': 8,
#   'po 10.5': 8,
#   'po 10.6': 7,
#   'po 10.7': 7,
#   'po 10.8': 7,
#   'po 10.9': 7,
#   'po 100.4': 1,
#   'po 101.1': 1,
#   'po 101.2': 1,
#   'po 102.4': 1,
#   'po 103.0': 1,
#   'po 105.5': 1,
#   'po 11.0': 7,
#   'po 11.1': 7,
#   'po 11.2': 7,
#   'po 11.3': 8,
#   'po 11.4': 8,
#   'po 11.5': 7,
#   'po 11.6': 7,
#   'po 11.7': 7,
#   'po 11.8': 7,
#   'po 11.9': 7,
#   'po 12.0': 7,
#   'po 12.1': 6,
#   'po 12.2': 6,
#   'po 12.3': 6,
#   'po 12.4': 6,
#   'po 12.5': 6,
#   'po 12.6': 6,
#   'po 12.7': 7,
#   'po 12.8': 6,
#   'po 12.9': 6,
#   'po 13.0': 6,
#   'po 13.1': 6,
#   'po 13.2': 6,
#   'po 13.3': 6,
#   'po 13.4': 6,
#   'po 13.5': 5,
#   'po 13.6': 5,
#   'po 13.7': 6,
#   'po 13.8': 5,
#   'po 13.9': 5,
#   'po 14.0': 6,
#   'po 14.1': 5,
#   'po 14.2': 5,
#   'po 14.3': 6,
#   'po 14.4': 5,
#   'po 14.5': 5,
#   'po 14.6': 5,
#   'po 14.7': 5,
#   'po 14.8': 5,
#   'po 14.9': 5,
#   'po 15.0': 5,
#   'po 15.1': 5,
#   'po 15.2': 5,
#   'po 15.3': 5,
#   'po 15.4': 5,
#   'po 15.5': 4,
#   'po 15.6': 5,
#   'po 15.7': 4,
#   'po 15.8': 5,
#   'po 15.9': 4,
#   'po 16.0': 5,
#   'po 16.1': 5,
#   'po 16.2': 4,
#   'po 16.3': 5,
#   'po 16.4': 5,
#   'po 16.5': 5,
#   'po 16.6': 5,
#   'po 16.7': 5,
#   'po 16.8': 4,
#   'po 16.9': 5,
#   'po 17.0': 5,
#   'po 17.1': 5,
#   'po 17.2': 5,
#   'po 17.3': 4,
#   'po 17.4': 4,
#   'po 17.5': 4,
#   'po 17.6': 4,
#   'po 17.7': 4,
#   'po 17.8': 4,
#   'po 17.9': 4,
#   'po 18.0': 4,
#   'po 18.1': 4,
#   'po 18.2': 4,
#   'po 18.3': 4,
#   'po 18.4': 4,
#   'po 18.5': 4,
#   'po 18.6': 4,
#   'po 18.7': 4,
#   'po 18.8': 4,
#   'po 18.9': 4,
#   'po 19.0': 3,
#   'po 19.1': 4,
#   'po 19.2': 4,
#   'po 19.3': 4,
#   'po 19.4': 4,
#   'po 19.5': 4,
#   'po 19.6': 4,
#   'po 19.7': 4,
#   'po 19.8': 3,
#   'po 19.9': 4,
#   'po 2.0': 19,
#   'po 2.1': 19,
#   'po 2.2': 18,
#   'po 2.3': 17,
#   'po 2.4': 17,
#   'po 2.5': 16,
#   'po 2.6': 16,
#   'po 2.7': 15,
#   'po 2.8': 15,
#   'po 2.9': 15,
#   'po 20.0': 4,
#   'po 20.1': 4,
#   'po 20.2': 4,
#   'po 20.3': 4,
#   'po 20.4': 3,
#   'po 20.5': 4,
#   'po 20.6': 3,
#   'po 20.7': 4,
#   'po 20.8': 4,
#   'po 20.9': 3,
#   'po 21.0': 3,
#   'po 21.1': 3,
#   'po 21.2': 3,
#   'po 21.3': 3,
#   'po 21.4': 3,
#   'po 21.5': 3,
#   'po 21.6': 3,
#   'po 21.7': 4,
#   'po 21.8': 3,
#   'po 21.9': 3,
#   'po 22.0': 3,
#   'po 22.1': 4,
#   'po 22.2': 3,
#   'po 22.3': 3,
#   'po 22.4': 3,
#   'po 22.5': 3,
#   'po 22.6': 3,
#   'po 22.7': 3,
#   'po 22.8': 3,
#   'po 22.9': 3,
#   'po 23.0': 3,
#   'po 23.1': 3,
#   'po 23.2': 3,
#   'po 23.3': 3,
#   'po 23.4': 3,
#   'po 23.5': 3,
#   'po 23.6': 3,
#   'po 23.7': 3,
#   'po 23.8': 3,
#   'po 23.9': 3,
#   'po 24.0': 3,
#   'po 24.1': 3,
#   'po 24.2': 3,
#   'po 24.3': 3,
#   'po 24.4': 3,
#   'po 24.5': 3,
#   'po 24.6': 3,
#   'po 24.7': 3,
#   'po 24.8': 3,
#   'po 24.9': 3,
#   'po 25.0': 3,
#   'po 25.1': 3,
#   'po 25.2': 3,
#   'po 25.3': 3,
#   'po 25.4': 3,
#   'po 25.5': 3,
#   'po 25.6': 3,
#   'po 25.7': 3,
#   'po 25.8': 3,
#   'po 25.9': 3,
#   'po 26.0': 3,
#   'po 26.1': 3,
#   'po 26.2': 3,
#   'po 26.3': 2,
#   'po 26.4': 3,
#   'po 26.5': 3,
#   'po 26.6': 2,
#   'po 26.7': 3,
#   'po 26.8': 3,
#   'po 26.9': 3,
#   'po 27.0': 3,
#   'po 27.1': 2,
#   'po 27.2': 3,
#   'po 27.3': 3,
#   'po 27.4': 3,
#   'po 27.5': 2,
#   'po 27.6': 3,
#   'po 27.7': 2,
#   'po 27.8': 2,
#   'po 27.9': 3,
#   'po 28.0': 2,
#   'po 28.1': 2,
#   'po 28.2': 2,
#   'po 28.3': 2,
#   'po 28.4': 2,
#   'po 28.5': 2,
#   'po 28.6': 2,
#   'po 28.7': 3,
#   'po 28.8': 2,
#   'po 28.9': 3,
#   'po 29.0': 2,
#   'po 29.1': 2,
#   'po 29.2': 2,
#   'po 29.3': 2,
#   'po 29.4': 2,
#   'po 29.5': 2,
#   'po 29.6': 2,
#   'po 29.7': 2,
#   'po 29.8': 2,
#   'po 29.9': 2,
#   'po 3.0': 14,
#   'po 3.1': 13,
#   'po 3.2': 13,
#   'po 3.3': 13,
#   'po 3.4': 12,
#   'po 3.5': 12,
#   'po 3.6': 12,
#   'po 3.7': 12,
#   'po 3.8': 11,
#   'po 3.9': 10,
#   'po 30.0': 4,
#   'po 30.1': 3,
#   'po 30.2': 3,
#   'po 30.3': 3,
#   'po 30.4': 3,
#   'po 30.5': 3,
#   'po 30.6': 3,
#   'po 30.7': 3,
#   'po 30.8': 3,
#   'po 30.9': 3,
#   'po 31.0': 3,
#   'po 31.1': 3,
#   'po 31.2': 3,
#   'po 31.3': 3,
#   'po 31.4': 3,
#   'po 31.5': 3,
#   'po 31.6': 3,
#   'po 31.7': 3,
#   'po 31.8': 2,
#   'po 31.9': 3,
#   'po 32.0': 3,
#   'po 32.1': 3,
#   'po 32.2': 3,
#   'po 32.3': 3,
#   'po 32.4': 3,
#   'po 32.5': 3,
#   'po 32.6': 2,
#   'po 32.7': 2,
#   'po 32.8': 3,
#   'po 32.9': 2,
#   'po 33.0': 3,
#   'po 33.1': 3,
#   'po 33.2': 3,
#   'po 33.3': 2,
#   'po 33.4': 3,
#   'po 33.5': 2,
#   'po 33.6': 3,
#   'po 33.7': 3,
#   'po 33.8': 3,
#   'po 33.9': 2,
#   'po 34.0': 3,
#   'po 34.1': 2,
#   'po 34.2': 2,
#   'po 34.3': 2,
#   'po 34.4': 2,
#   'po 34.5': 3,
#   'po 34.6': 2,
#   'po 34.7': 3,
#   'po 34.8': 2,
#   'po 34.9': 2,
#   'po 35.0': 3,
#   'po 35.1': 3,
#   'po 35.2': 2,
#   'po 35.3': 2,
#   'po 35.4': 2,
#   'po 35.5': 3,
#   'po 35.6': 3,
#   'po 35.7': 2,
#   'po 35.8': 2,
#   'po 35.9': 2,
#   'po 36.0': 2,
#   'po 36.1': 2,
#   'po 36.2': 2,
#   'po 36.3': 2,
#   'po 36.4': 2,
#   'po 36.5': 2,
#   'po 36.6': 2,
#   'po 36.7': 2,
#   'po 36.8': 2,
#   'po 36.9': 2,
#   'po 37.0': 2,
#   'po 37.1': 2,
#   'po 37.2': 2,
#   'po 37.3': 2,
#   'po 37.4': 2,
#   'po 37.5': 2,
#   'po 37.6': 2,
#   'po 37.7': 2,
#   'po 37.8': 2,
#   'po 37.9': 2,
#   'po 38.0': 2,
#   'po 38.1': 2,
#   'po 38.2': 2,
#   'po 38.3': 2,
#   'po 38.4': 2,
#   'po 38.5': 2,
#   'po 38.6': 2,
#   'po 38.7': 2,
#   'po 38.8': 2,
#   'po 38.9': 2,
#   'po 39.0': 2,
#   'po 39.1': 2,
#   'po 39.2': 2,
#   'po 39.3': 2,
#   'po 39.4': 2,
#   'po 39.5': 2,
#   'po 39.6': 2,
#   'po 39.7': 2,
#   'po 39.8': 2,
#   'po 39.9': 2,
#   'po 4.0': 11,
#   'po 4.1': 10,
#   'po 4.2': 10,
#   'po 4.3': 10,
#   'po 4.4': 9,
#   'po 4.5': 10,
#   'po 4.6': 9,
#   'po 4.7': 10,
#   'po 4.8': 9,
#   'po 4.9': 9,
#   'po 40.0': 2,
#   'po 40.1': 2,
#   'po 40.2': 2,
#   'po 40.3': 2,
#   'po 40.4': 2,
#   'po 40.5': 2,
#   'po 40.6': 2,
#   'po 40.7': 2,
#   'po 40.8': 2,
#   'po 40.9': 2,
#   'po 41.0': 2,
#   'po 41.1': 2,
#   'po 41.2': 2,
#   'po 41.3': 1,
#   'po 41.4': 2,
#   'po 41.5': 2,
#   'po 41.6': 2,
#   'po 41.7': 2,
#   'po 41.8': 2,
#   'po 41.9': 2,
#   'po 42.0': 2,
#   'po 42.1': 2,
#   'po 42.2': 2,
#   'po 42.3': 2,
#   'po 42.4': 2,
#   'po 42.5': 2,
#   'po 42.6': 2,
#   'po 42.7': 1,
#   'po 42.8': 2,
#   'po 42.9': 2,
#   'po 43.0': 2,
#   'po 43.1': 2,
#   'po 43.2': 2,
#   'po 43.3': 2,
#   'po 43.4': 2,
#   'po 43.5': 2,
#   'po 43.6': 2,
#   'po 43.7': 2,
#   'po 43.8': 2,
#   'po 43.9': 2,
#   'po 44.0': 2,
#   'po 44.1': 2,
#   'po 44.2': 2,
#   'po 44.3': 2,
#   'po 44.4': 1,
#   'po 44.5': 2,
#   'po 44.6': 2,
#   'po 44.7': 1,
#   'po 44.8': 2,
#   'po 44.9': 2,
#   'po 45.0': 1,
#   'po 45.1': 1,
#   'po 45.2': 2,
#   'po 45.3': 1,
#   'po 45.4': 1,
#   'po 45.5': 1,
#   'po 45.6': 2,
#   'po 45.7': 2,
#   'po 45.8': 2,
#   'po 45.9': 1,
#   'po 46.0': 1,
#   'po 46.1': 2,
#   'po 46.2': 2,
#   'po 46.3': 2,
#   'po 46.4': 1,
#   'po 46.5': 1,
#   'po 46.6': 2,
#   'po 46.7': 1,
#   'po 46.8': 1,
#   'po 46.9': 1,
#   'po 47.0': 1,
#   'po 47.1': 1,
#   'po 47.2': 1,
#   'po 47.3': 2,
#   'po 47.4': 2,
#   'po 47.5': 1,
#   'po 47.6': 1,
#   'po 47.7': 1,
#   'po 47.8': 1,
#   'po 47.9': 1,
#   'po 48.0': 2,
#   'po 48.1': 1,
#   'po 48.2': 1,
#   'po 48.3': 1,
#   'po 48.4': 1,
#   'po 48.5': 1,
#   'po 48.6': 1,
#   'po 48.7': 1,
#   'po 48.8': 1,
#   'po 48.9': 1,
#   'po 49.0': 1,
#   'po 49.1': 1,
#   'po 49.2': 1,
#   'po 49.3': 1,
#   'po 49.4': 1,
#   'po 49.5': 1,
#   'po 49.6': 1,
#   'po 49.7': 1,
#   'po 49.8': 1,
#   'po 49.9': 1,
#   'po 5.0': 9,
#   'po 5.1': 8,
#   'po 5.2': 8,
#   'po 5.3': 8,
#   'po 5.4': 7,
#   'po 5.5': 8,
#   'po 5.6': 8,
#   'po 5.7': 7,
#   'po 5.8': 7,
#   'po 5.9': 7,
#   'po 50.0': 1,
#   'po 50.1': 1,
#   'po 50.2': 1,
#   'po 50.3': 1,
#   'po 50.4': 1,
#   'po 50.5': 1,
#   'po 50.6': 1,
#   'po 50.7': 1,
#   'po 50.8': 1,
#   'po 50.9': 1,
#   'po 51.0': 1,
#   'po 51.1': 1,
#   'po 51.2': 1,
#   'po 51.3': 1,
#   'po 51.4': 1,
#   'po 51.5': 1,
#   'po 51.6': 1,
#   'po 51.7': 1,
#   'po 51.8': 2,
#   'po 51.9': 1,
#   'po 52.0': 1,
#   'po 52.1': 1,
#   'po 52.2': 1,
#   'po 52.3': 1,
#   'po 52.4': 1,
#   'po 52.5': 1,
#   'po 52.6': 1,
#   'po 52.7': 1,
#   'po 52.8': 1,
#   'po 52.9': 1,
#   'po 53.0': 1,
#   'po 53.1': 1,
#   'po 53.2': 1,
#   'po 53.3': 1,
#   'po 53.4': 1,
#   'po 53.5': 1,
#   'po 53.6': 1,
#   'po 53.7': 1,
#   'po 53.8': 1,
#   'po 53.9': 1,
#   'po 54.0': 1,
#   'po 54.1': 1,
#   'po 54.2': 1,
#   'po 54.3': 1,
#   'po 54.4': 1,
#   'po 54.5': 1,
#   'po 54.6': 1,
#   'po 54.7': 1,
#   'po 54.8': 1,
#   'po 54.9': 1,
#   'po 55.0': 1,
#   'po 55.1': 1,
#   'po 55.2': 1,
#   'po 55.3': 1,
#   'po 55.4': 1,
#   'po 55.5': 1,
#   'po 55.6': 1,
#   'po 55.7': 1,
#   'po 55.8': 1,
#   'po 55.9': 1,
#   'po 56.0': 1,
#   'po 56.1': 1,
#   'po 56.2': 1,
#   'po 56.3': 1,
#   'po 56.4': 1,
#   'po 56.5': 1,
#   'po 56.6': 1,
#   'po 56.7': 1,
#   'po 56.8': 1,
#   'po 56.9': 1,
#   'po 57.0': 1,
#   'po 57.1': 1,
#   'po 57.2': 1,
#   'po 57.3': 1,
#   'po 57.4': 1,
#   'po 57.5': 1,
#   'po 57.6': 1,
#   'po 57.7': 1,
#   'po 57.8': 1,
#   'po 57.9': 1,
#   'po 58.0': 1,
#   'po 58.1': 1,
#   'po 58.2': 1,
#   'po 58.3': 1,
#   'po 58.4': 1,
#   'po 58.5': 1,
#   'po 58.6': 1,
#   'po 58.7': 1,
#   'po 58.8': 1,
#   'po 58.9': 1,
#   'po 59.0': 1,
#   'po 59.1': 1,
#   'po 59.2': 1,
#   'po 59.3': 1,
#   'po 59.4': 1,
#   'po 59.5': 1,
#   'po 59.6': 1,
#   'po 59.7': 1,
#   'po 59.8': 1,
#   'po 59.9': 1,
#   'po 6.0': 7,
#   'po 6.1': 7,
#   'po 6.2': 7,
#   'po 6.3': 7,
#   'po 6.4': 7,
#   'po 6.5': 6,
#   'po 6.6': 7,
#   'po 6.7': 7,
#   'po 6.8': 7,
#   'po 6.9': 6,
#   'po 60.0': 1,
#   'po 60.1': 1,
#   'po 60.2': 1,
#   'po 60.3': 1,
#   'po 60.4': 1,
#   'po 60.5': 1,
#   'po 60.6': 1,
#   'po 60.7': 1,
#   'po 60.8': 1,
#   'po 60.9': 1,
#   'po 61.0': 1,
#   'po 61.1': 1,
#   'po 61.2': 1,
#   'po 61.3': 1,
#   'po 61.4': 1,
#   'po 61.5': 1,
#   'po 61.6': 1,
#   'po 61.7': 1,
#   'po 61.8': 1,
#   'po 61.9': 1,
#   'po 62.0': 1,
#   'po 62.1': 1,
#   'po 62.2': 1,
#   'po 62.3': 1,
#   'po 62.4': 1,
#   'po 62.5': 1,
#   'po 62.6': 1,
#   'po 62.7': 1,
#   'po 62.8': 1,
#   'po 62.9': 1,
#   'po 63.0': 1,
#   'po 63.1': 1,
#   'po 63.2': 1,
#   'po 63.3': 1,
#   'po 63.4': 1,
#   'po 63.6': 1,
#   'po 63.7': 1,
#   'po 63.8': 1,
#   'po 63.9': 1,
#   'po 64.0': 1,
#   'po 64.1': 1,
#   'po 64.2': 1,
#   'po 64.3': 1,
#   'po 64.4': 1,
#   'po 64.5': 1,
#   'po 64.6': 1,
#   'po 64.7': 1,
#   'po 64.8': 1,
#   'po 64.9': 1,
#   'po 65.0': 1,
#   'po 65.1': 1,
#   'po 65.2': 1,
#   'po 65.3': 1,
#   'po 65.4': 1,
#   'po 65.5': 1,
#   'po 65.6': 1,
#   'po 65.7': 1,
#   'po 65.8': 1,
#   'po 65.9': 1,
#   'po 66.0': 1,
#   'po 66.1': 1,
#   'po 66.2': 1,
#   'po 66.3': 1,
#   'po 66.4': 1,
#   'po 66.5': 1,
#   'po 66.6': 1,
#   'po 66.7': 1,
#   'po 66.8': 1,
#   'po 66.9': 1,
#   'po 67.0': 1,
#   'po 67.1': 1,
#   'po 67.2': 1,
#   'po 67.3': 1,
#   'po 67.4': 1,
#   'po 67.5': 1,
#   'po 67.6': 1,
#   'po 67.7': 1,
#   'po 67.8': 1,
#   'po 67.9': 1,
#   'po 68.0': 1,
#   'po 68.1': 1,
#   'po 68.2': 1,
#   'po 68.3': 1,
#   'po 68.5': 1,
#   'po 68.6': 1,
#   'po 68.7': 1,
#   'po 68.8': 1,
#   'po 68.9': 1,
#   'po 69.0': 1,
#   'po 69.1': 1,
#   'po 69.2': 1,
#   'po 69.3': 1,
#   'po 69.4': 1,
#   'po 69.5': 1,
#   'po 69.6': 1,
#   'po 69.7': 1,
#   'po 69.8': 1,
#   'po 69.9': 1,
#   'po 7.0': 6,
#   'po 7.1': 6,
#   'po 7.2': 6,
#   'po 7.3': 6,
#   'po 7.4': 6,
#   'po 7.5': 6,
#   'po 7.6': 6,
#   'po 7.7': 5,
#   'po 7.8': 5,
#   'po 7.9': 5,
#   'po 70.0': 1,
#   'po 70.1': 1,
#   'po 70.2': 1,
#   'po 70.3': 1,
#   'po 70.4': 1,
#   'po 70.5': 1,
#   'po 70.7': 1,
#   'po 70.8': 1,
#   'po 70.9': 1,
#   'po 71.0': 1,
#   'po 71.1': 1,
#   'po 71.2': 1,
#   'po 71.3': 1,
#   'po 71.5': 1,
#   'po 71.6': 1,
#   'po 71.7': 1,
#   'po 71.8': 1,
#   'po 71.9': 1,
#   'po 72.0': 1,
#   'po 72.1': 1,
#   'po 72.2': 1,
#   'po 72.3': 1,
#   'po 72.4': 1,
#   'po 72.6': 1,
#   'po 72.8': 1,
#   'po 72.9': 1,
#   'po 73.0': 1,
#   'po 73.1': 1,
#   'po 73.2': 1,
#   'po 73.3': 1,
#   'po 73.4': 1,
#   'po 73.6': 1,
#   'po 73.7': 1,
#   'po 73.8': 1,
#   'po 74.0': 1,
#   'po 74.1': 1,
#   'po 74.3': 1,
#   'po 74.4': 1,
#   'po 74.5': 1,
#   'po 74.6': 1,
#   'po 75.0': 1,
#   'po 75.1': 1,
#   'po 75.2': 1,
#   'po 75.3': 1,
#   'po 75.4': 1,
#   'po 75.5': 1,
#   'po 75.6': 1,
#   'po 75.7': 1,
#   'po 76.1': 1,
#   'po 76.2': 1,
#   'po 76.3': 1,
#   'po 76.4': 1,
#   'po 76.8': 1,
#   'po 76.9': 1,
#   'po 77.0': 1,
#   'po 77.2': 1,
#   'po 77.5': 1,
#   'po 77.7': 1,
#   'po 77.9': 1,
#   'po 78.0': 1,
#   'po 78.1': 1,
#   'po 78.2': 1,
#   'po 78.6': 1,
#   'po 79.2': 1,
#   'po 79.3': 1,
#   'po 79.6': 1,
#   'po 79.9': 1,
#   'po 8.0': 6,
#   'po 8.1': 5,
#   'po 8.2': 6,
#   'po 8.3': 5,
#   'po 8.4': 5,
#   'po 8.5': 5,
#   'po 8.6': 5,
#   'po 8.7': 5,
#   'po 8.8': 5,
#   'po 8.9': 5,
#   'po 80.2': 1,
#   'po 80.5': 1,
#   'po 80.7': 1,
#   'po 81.2': 1,
#   'po 82.2': 1,
#   'po 82.5': 1,
#   'po 83.4': 1,
#   'po 83.6': 1,
#   'po 84.1': 1,
#   'po 84.5': 1,
#   'po 84.9': 1,
#   'po 85.1': 1,
#   'po 85.4': 1,
#   'po 9.0': 5,
#   'po 9.1': 5,
#   'po 9.2': 5,
#   'po 9.3': 5,
#   'po 9.4': 5,
#   'po 9.5': 4,
#   'po 9.6': 5,
#   'po 9.7': 5,
#   'po 9.8': 4,
#   'po 9.9': 4,
#   'po>1000': 144,
#   'positive': 855},
#  'AKDDX5X': {'negative': 6},
#  'AUTIAEA': {'negative': 7},
#  'AY45OML': {'negative': 1},
#  'AZCLNW7': {'0.02(0)': 1, '<0.35(0)': 2},
#  'B4QVC4Z': {'bm°á°úâüá¶': 3, '°ñ¼öæçµ¶°á°ú âüá¶': 11},
#  'BCXGHUN': {'a': 5573,
#   'a1b3': 1,
#   'a2b': 5,
#   'a2b3': 2,
#   'a3': 1,
#   'ab': 1818,
#   'b': 4416,
#   'b3': 1,
#   'bmt': 13,
#   'o': 4472},
#  'BCXK7ST': {'negative': 19},
#  'BDW1GBV': {'negative': 7},
#  'BMU3EX9': {'neg(0.03)': 2,
#   'neg(0.04)': 9,
#   'neg(0.05)': 23,
#   'neg(0.06)': 44,
#   'neg(0.07)': 66,
#   'neg(0.08)': 72,
#   'neg(0.09)': 67,
#   'neg(0.10)': 52,
#   'neg(0.11)': 39,
#   'neg(0.12)': 29,
#   'neg(0.13)': 21,
#   'neg(0.14)': 16,
#   'neg(0.15)': 11,
#   'neg(0.16)': 10,
#   'neg(0.17)': 9,
#   'neg(0.18)': 7,
#   'neg(0.19)': 6,
#   'neg(0.20)': 5,
#   'neg(0.21)': 4,
#   'neg(0.22)': 4,
#   'neg(0.23)': 3,
#   'neg(0.24)': 3,
#   'neg(0.25)': 2,
#   'neg(0.26)': 2,
#   'neg(0.27)': 2,
#   'neg(0.28)': 2,
#   'neg(0.29)': 2,
#   'neg(0.30)': 1,
#   'neg(0.31)': 1,
#   'neg(0.32)': 1,
#   'neg(0.33)': 1,
#   'neg(0.34)': 1,
#   'neg(0.35)': 1,
#   'neg(0.36)': 1,
#   'neg(0.37)': 1,
#   'neg(0.38)': 1,
#   'neg(0.39)': 1,
#   'neg(0.43)': 1,
#   'neg(0.45)': 1,
#   'negative': 627,
#   'pos(0.004)': 10,
#   'pos(0.005)': 9,
#   'pos(0.006)': 15,
#   'pos(0.007)': 10,
#   'pos(0.008)': 2,
#   'pos(0.009)': 1,
#   'pos(0.049)': 1,
#   'pos(0.051)': 1,
#   'pos(0.052)': 1,
#   'pos(0.053)': 1,
#   'pos(0.054)': 1,
#   'pos(0.055)': 1,
#   'pos(0.056)': 1,
#   'pos(0.057)': 1,
#   'pos(0.058)': 1,
#   'pos(0.059)': 1,
#   'pos(0.060)': 1,
#   'pos(0.061)': 1,
#   'pos(0.062)': 1,
#   'pos(0.063)': 1,
#   'pos(0.064)': 1,
#   'pos(0.065)': 1,
#   'pos(0.066)': 1,
#   'pos(0.067)': 1,
#   'pos(0.068)': 1,
#   'pos(0.069)': 1,
#   'pos(0.070)': 1,
#   'pos(0.071)': 1,
#   'pos(0.072)': 1,
#   'pos(0.073)': 1,
#   'pos(0.074)': 1,
#   'pos(0.075)': 1,
#   'pos(0.076)': 1,
#   'pos(0.077)': 1,
#   'pos(0.078)': 1,
#   'pos(0.079)': 1,
#   'pos(0.080)': 1,
#   'pos(0.081)': 1,
#   'pos(0.083)': 1,
#   'positive': 484},
#  'BODIP82': {'negative': 6},
#  'BPNN4XD': {'neg': 19, 'negative': 126},
#  'BRWTJ09': {'neg': 91, 'negative': 852},
#  'BU6U2QE': {'non-reactive': 14},
#  'BWH9R6C': {'negative': 13},
#  'BWW14RO': {'negative': 6, 'pos(4)': 1},
#  'C1STH4K': {'negative': 14},
#  'C625D3P': {'negative': 14, 'pos(1:32)': 1, 'pos(1:64)': 1},
#  'C6T7RMH': {'negative': 3},
#  'CH6OZHX': {'neg(0.01)': 215,
#   'neg(0.02)': 3,
#   'neg(0.03)': 3,
#   'neg(0.04)': 4,
#   'neg(0.05)': 3,
#   'neg(0.06)': 4,
#   'neg(0.07)': 4,
#   'neg(0.08)': 4,
#   'neg(0.09)': 4,
#   'neg(0.10)': 4,
#   'neg(0.11)': 4,
#   'neg(0.12)': 4,
#   'neg(0.13)': 4,
#   'neg(0.14)': 4,
#   'neg(0.15)': 4,
#   'neg(0.16)': 4,
#   'neg(0.17)': 4,
#   'neg(0.18)': 4,
#   'neg(0.19)': 3,
#   'neg(0.20)': 4,
#   'neg(0.21)': 3,
#   'neg(0.22)': 3,
#   'neg(0.23)': 3,
#   'neg(0.24)': 4,
#   'neg(0.25)': 4,
#   'neg(0.26)': 4,
#   'neg(0.27)': 3,
#   'neg(0.28)': 3,
#   'neg(0.29)': 3,
#   'neg(0.30)': 3,
#   'neg(0.31)': 3,
#   'neg(0.32)': 3,
#   'neg(0.33)': 3,
#   'neg(0.34)': 3,
#   'neg(0.35)': 3,
#   'neg(0.36)': 3,
#   'neg(0.37)': 3,
#   'neg(0.38)': 3,
#   'neg(0.39)': 3,
#   'neg(0.40)': 3,
#   'neg(0.41)': 3,
#   'neg(0.42)': 3,
#   'neg(0.43)': 3,
#   'neg(0.44)': 3,
#   'neg(0.45)': 2,
#   'neg(0.46)': 3,
#   'neg(0.47)': 3,
#   'neg(0.48)': 3,
#   'neg(0.49)': 3,
#   'neg(0.50)': 2,
#   'neg(0.51)': 3,
#   'neg(0.52)': 2,
#   'neg(0.53)': 2,
#   'neg(0.54)': 2,
#   'neg(0.55)': 2,
#   'neg(0.56)': 2,
#   'neg(0.57)': 2,
#   'neg(0.58)': 2,
#   'neg(0.59)': 2,
#   'neg(0.60)': 2,
#   'neg(0.61)': 2,
#   'neg(0.62)': 2,
#   'neg(0.63)': 2,
#   'neg(0.64)': 2,
#   'neg(0.65)': 2,
#   'neg(0.66)': 2,
#   'neg(0.67)': 2,
#   'neg(0.68)': 1,
#   'neg(0.69)': 1,
#   'neg(0.70)': 2,
#   'neg(0.71)': 1,
#   'neg(0.72)': 1,
#   'neg(0.73)': 1,
#   'neg(0.74)': 1,
#   'neg(0.75)': 1,
#   'neg(0.76)': 1,
#   'neg(0.77)': 1,
#   'neg(0.78)': 1,
#   'neg(0.79)': 1,
#   'neg(0.80)': 1,
#   'neg(0.81)': 1,
#   'neg(0.82)': 1,
#   'neg(0.83)': 1,
#   'neg(0.84)': 1,
#   'neg(0.85)': 1,
#   'neg(0.86)': 1,
#   'neg(0.87)': 1,
#   'neg(0.88)': 1,
#   'neg(0.89)': 1,
#   'neg(0.90)': 1,
#   'neg(0.91)': 1,
#   'neg(0.92)': 1,
#   'neg(0.93)': 1,
#   'neg(0.94)': 1,
#   'neg(0.95)': 1,
#   'neg(0.96)': 1,
#   'neg(0.97)': 1,
#   'neg(0.98)': 1,
#   'neg(0.99)': 1,
#   'neg(1.00)': 1,
#   'neg(1.01)': 1,
#   'neg(1.02)': 1,
#   'neg(1.03)': 1,
#   'neg(1.04)': 1,
#   'neg(1.05)': 1,
#   'neg(1.06)': 1,
#   'neg(1.07)': 1,
#   'neg(1.08)': 1,
#   'neg(1.09)': 1,
#   'neg(1.10)': 1,
#   'neg(1.12)': 1,
#   'neg(1.14)': 1,
#   'neg(1.15)': 1,
#   'neg(1.16)': 1,
#   'neg(1.17)': 1,
#   'neg(1.18)': 1,
#   'neg(1.19)': 1,
#   'neg(1.25)': 1,
#   'neg(1.27)': 1,
#   'neg(1.38)': 1,
#   'neg(1.42)': 1,
#   'neg(2.00)': 1388,
#   'neg(2.01)': 1,
#   'neg(2.02)': 1,
#   'neg(2.03)': 1,
#   'neg(2.04)': 1,
#   'neg(2.05)': 1,
#   'neg(2.06)': 1,
#   'neg(2.07)': 1,
#   'neg(2.08)': 1,
#   'neg(2.09)': 1,
#   'neg(2.10)': 1,
#   'neg(2.11)': 1,
#   'neg(2.12)': 1,
#   'neg(2.13)': 1,
#   'neg(2.14)': 1,
#   'neg(2.15)': 1,
#   'neg(2.16)': 1,
#   'neg(2.17)': 1,
#   'neg(2.18)': 1,
#   'neg(2.19)': 1,
#   'neg(2.20)': 1,
#   'neg(2.21)': 1,
#   'neg(2.22)': 1,
#   'neg(2.23)': 1,
#   'neg(2.24)': 1,
#   'neg(2.25)': 1,
#   'neg(2.26)': 1,
#   'neg(2.27)': 1,
#   'neg(2.28)': 1,
#   'neg(2.29)': 1,
#   'neg(2.30)': 1,
#   'neg(2.31)': 1,
#   'neg(2.32)': 1,
#   'neg(2.33)': 1,
#   'neg(2.34)': 1,
#   'neg(2.35)': 1,
#   'neg(2.36)': 1,
#   'neg(2.37)': 1,
#   'neg(2.38)': 1,
#   'neg(2.39)': 1,
#   'neg(2.40)': 1,
#   'neg(2.41)': 1,
#   'neg(2.42)': 1,
#   'neg(2.43)': 1,
#   'neg(2.44)': 1,
#   'neg(2.45)': 1,
#   'neg(2.46)': 1,
#   'neg(2.47)': 1,
#   'neg(2.49)': 1,
#   'neg(2.50)': 1,
#   'neg(2.51)': 1,
#   'neg(2.52)': 1,
#   'neg(2.53)': 1,
#   'neg(2.54)': 1,
#   'neg(2.55)': 1,
#   'neg(2.56)': 1,
#   'neg(2.57)': 1,
#   'neg(2.58)': 1,
#   'neg(2.59)': 1,
#   'neg(2.60)': 1,
#   'neg(2.61)': 1,
#   'neg(2.62)': 1,
#   'neg(2.63)': 1,
#   'neg(2.65)': 1,
#   'neg(2.66)': 1,
#   'neg(2.67)': 1,
#   'neg(2.68)': 1,
#   'neg(2.69)': 1,
#   'neg(2.70)': 1,
#   'neg(2.71)': 1,
#   'neg(2.72)': 1,
#   'neg(2.73)': 1,
#   'neg(2.74)': 1,
#   'neg(2.75)': 1,
#   'neg(2.76)': 1,
#   'neg(2.77)': 1,
#   'neg(2.78)': 1,
#   'neg(2.79)': 1,
#   'neg(2.80)': 1,
#   'neg(2.81)': 1,
#   'neg(2.84)': 1,
#   'neg(2.86)': 1,
#   'neg(2.87)': 1,
#   'neg(2.88)': 1,
#   'neg(2.89)': 1,
#   'neg(2.90)': 1,
#   'neg(2.92)': 1,
#   'neg(2.93)': 1,
#   'neg(2.94)': 1,
#   'neg(2.96)': 1,
#   'neg(2.97)': 1,
#   'neg(2.98)': 1,
#   'neg(2.99)': 1,
#   'neg(3.00)': 1,
#   'neg(3.01)': 1,
#   'neg(3.03)': 1,
#   'neg(3.04)': 1,
#   'neg(3.05)': 1,
#   'neg(3.08)': 1,
#   'neg(3.09)': 1,
#   'neg(3.10)': 1,
#   'neg(3.11)': 1,
#   'neg(3.12)': 1,
#   'neg(3.13)': 1,
#   'neg(3.14)': 1,
#   'neg(3.15)': 1,
#   'neg(3.16)': 1,
#   'neg(3.18)': 1,
#   'neg(3.19)': 1,
#   'neg(3.20)': 1,
#   'neg(3.21)': 1,
#   'neg(3.22)': 1,
#   'neg(3.23)': 1,
#   'neg(3.24)': 1,
#   'neg(3.25)': 1,
#   'neg(3.26)': 1,
#   'neg(3.29)': 1,
#   'neg(3.30)': 1,
#   'neg(3.31)': 1,
#   'neg(3.33)': 1,
#   'neg(3.34)': 1,
#   'neg(3.35)': 1,
#   'neg(3.37)': 1,
#   'neg(3.38)': 1,
#   'neg(3.39)': 1,
#   'neg(3.40)': 1,
#   'neg(3.41)': 1,
#   'neg(3.42)': 1,
#   'neg(3.43)': 1,
#   'neg(3.45)': 1,
#   'neg(3.46)': 1,
#   'neg(3.47)': 1,
#   'neg(3.48)': 1,
#   'neg(3.49)': 1,
#   'neg(3.50)': 1,
#   'neg(3.51)': 1,
#   'neg(3.53)': 1,
#   'neg(3.54)': 1,
#   'neg(3.55)': 1,
#   'neg(3.61)': 1,
#   'neg(3.62)': 1,
#   'neg(3.63)': 1,
#   'neg(3.64)': 1,
#   'neg(3.65)': 1,
#   'neg(3.68)': 1,
#   'neg(3.72)': 1,
#   'neg(3.73)': 1,
#   'neg(3.75)': 1,
#   'neg(3.77)': 1,
#   'neg(3.78)': 1,
#   'neg(3.79)': 1,
#   'neg(3.81)': 1,
#   'neg(3.82)': 1,
#   'neg(3.87)': 1,
#   'neg(3.88)': 1,
#   'neg(3.90)': 1,
#   'neg(3.91)': 1,
#   'neg(3.93)': 1,
#   'neg(3.95)': 1,
#   'neg(3.96)': 1,
#   'neg(4.00)': 1,
#   'neg(4.03)': 1,
#   'neg(4.04)': 1,
#   'neg(4.07)': 1,
#   'neg(4.09)': 1,
#   'neg(4.12)': 1,
#   'neg(4.13)': 1,
#   'neg(4.14)': 1,
#   'neg(4.16)': 1,
#   'neg(4.17)': 1,
#   'neg(4.23)': 1,
#   'neg(4.25)': 1,
#   'neg(4.26)': 1,
#   'neg(4.27)': 1,
#   'neg(4.29)': 1,
#   'neg(4.30)': 1,
#   'neg(4.41)': 1,
#   'neg(4.49)': 1,
#   'neg(4.54)': 1,
#   'neg(4.62)': 1,
#   'neg(4.63)': 1,
#   'neg(4.82)': 1,
#   'neg(5.05)': 1,
#   'neg(5.09)': 1,
#   'neg(5.21)': 1,
#   'neg(5.25)': 1,
#   'neg(5.31)': 1,
#   'neg(5.42)': 1,
#   'neg(5.89)': 1,
#   'negative': 1207,
#   'pos(10.0)': 1,
#   'pos(10.1)': 1,
#   'pos(10.2)': 1,
#   'pos(10.3)': 1,
#   'pos(10.4)': 1,
#   'pos(10.5)': 1,
#   'pos(10.6)': 1,
#   'pos(10.7)': 1,
#   'pos(10.8)': 1,
#   'pos(10.9)': 1,
#   'pos(100.1)': 1,
#   'pos(100.2)': 1,
#   'pos(100.3)': 1,
#   'pos(100.4)': 1,
#   'pos(100.5)': 1,
#   'pos(100.6)': 1,
#   'pos(100.7)': 1,
#   'pos(100.8)': 1,
#   'pos(100.9)': 1,
#   'pos(101.0)': 1,
#   'pos(101.1)': 1,
#   'pos(101.2)': 1,
#   'pos(101.3)': 1,
#   'pos(101.4)': 1,
#   'pos(101.5)': 1,
#   'pos(101.6)': 1,
#   'pos(101.7)': 1,
#   'pos(101.8)': 1,
#   'pos(101.9)': 1,
#   'pos(102.0)': 1,
#   'pos(102.1)': 1,
#   'pos(102.2)': 1,
#   'pos(102.3)': 1,
#   'pos(102.4)': 1,
#   'pos(102.5)': 1,
#   'pos(102.6)': 1,
#   'pos(102.7)': 1,
#   'pos(102.8)': 1,
#   'pos(102.9)': 1,
#   'pos(103.0)': 1,
#   'pos(103.1)': 1,
#   'pos(103.2)': 1,
#   'pos(103.3)': 1,
#   'pos(103.4)': 1,
#   'pos(103.5)': 1,
#   'pos(103.6)': 1,
#   'pos(103.7)': 1,
#   'pos(103.8)': 1,
#   'pos(103.9)': 1,
#   'pos(104.0)': 1,
#   'pos(104.1)': 1,
#   'pos(104.2)': 1,
#   'pos(104.3)': 1,
#   'pos(104.4)': 1,
#   'pos(104.5)': 1,
#   'pos(104.6)': 1,
#   'pos(104.7)': 1,
#   'pos(104.8)': 1,
#   'pos(104.9)': 1,
#   'pos(105.0)': 1,
#   'pos(105.1)': 1,
#   'pos(105.2)': 1,
#   'pos(105.3)': 1,
#   'pos(105.4)': 1,
#   'pos(105.5)': 1,
#   'pos(105.6)': 1,
#   'pos(105.7)': 1,
#   'pos(105.8)': 1,
#   'pos(105.9)': 1,
#   'pos(106.0)': 1,
#   'pos(106.1)': 1,
#   'pos(106.2)': 1,
#   'pos(106.3)': 1,
#   'pos(106.4)': 1,
#   'pos(106.5)': 1,
#   'pos(106.6)': 1,
#   'pos(106.7)': 1,
#   'pos(106.8)': 1,
#   'pos(106.9)': 1,
#   'pos(107.0)': 1,
#   'pos(107.1)': 1,
#   'pos(107.2)': 1,
#   'pos(107.3)': 1,
#   'pos(107.4)': 1,
#   'pos(107.6)': 1,
#   'pos(107.7)': 1,
#   'pos(107.8)': 1,
#   'pos(107.9)': 1,
#   'pos(108.0)': 1,
#   'pos(108.1)': 1,
#   'pos(108.2)': 1,
#   'pos(108.3)': 1,
#   'pos(108.4)': 1,
#   'pos(108.5)': 1,
#   'pos(108.6)': 1,
#   'pos(108.7)': 1,
#   'pos(108.8)': 1,
#   'pos(108.9)': 1,
#   'pos(109.0)': 1,
#   'pos(109.1)': 1,
#   'pos(109.3)': 1,
#   'pos(109.4)': 1,
#   'pos(109.5)': 1,
#   'pos(109.6)': 1,
#   'pos(109.7)': 1,
#   'pos(109.8)': 1,
#   'pos(109.9)': 1,
#   'pos(11.0)': 1,
#   'pos(11.1)': 1,
#   'pos(11.2)': 1,
#   'pos(11.3)': 1,
#   'pos(11.4)': 1,
#   'pos(11.5)': 1,
#   'pos(11.6)': 1,
#   'pos(11.7)': 1,
#   'pos(11.8)': 1,
#   'pos(11.9)': 1,
#   'pos(110.0)': 1,
#   'pos(110.1)': 1,
#   'pos(110.2)': 1,
#   'pos(110.3)': 1,
#   'pos(110.4)': 1,
#   'pos(110.5)': 1,
#   'pos(110.6)': 1,
#   'pos(110.8)': 1,
#   'pos(110.9)': 1,
#   'pos(111.0)': 1,
#   'pos(111.1)': 1,
#   'pos(111.2)': 1,
#   'pos(111.3)': 1,
#   'pos(111.4)': 1,
#   'pos(111.5)': 1,
#   'pos(111.6)': 1,
#   'pos(111.7)': 1,
#   'pos(111.8)': 1,
#   'pos(111.9)': 1,
#   'pos(112.1)': 1,
#   'pos(112.2)': 1,
#   'pos(112.3)': 1,
#   'pos(112.4)': 1,
#   'pos(112.5)': 1,
#   'pos(112.6)': 1,
#   'pos(112.7)': 1,
#   'pos(112.8)': 1,
#   'pos(112.9)': 1,
#   'pos(113.0)': 1,
#   'pos(113.1)': 1,
#   'pos(113.3)': 1,
#   'pos(113.4)': 1,
#   'pos(113.5)': 1,
#   'pos(113.6)': 1,
#   'pos(113.7)': 1,
#   'pos(113.8)': 1,
#   'pos(113.9)': 1,
#   'pos(114.0)': 1,
#   'pos(114.1)': 1,
#   'pos(114.2)': 1,
#   'pos(114.3)': 1,
#   'pos(114.4)': 1,
#   'pos(114.5)': 1,
#   'pos(114.6)': 1,
#   'pos(114.7)': 1,
#   'pos(114.8)': 1,
#   'pos(114.9)': 1,
#   'pos(115.1)': 1,
#   'pos(115.2)': 1,
#   'pos(115.3)': 1,
#   'pos(115.4)': 1,
#   'pos(115.5)': 1,
#   'pos(115.6)': 1,
#   'pos(115.7)': 1,
#   'pos(115.8)': 1,
#   'pos(115.9)': 1,
#   'pos(116.0)': 1,
#   'pos(116.1)': 1,
#   'pos(116.2)': 1,
#   'pos(116.3)': 1,
#   'pos(116.4)': 1,
#   'pos(116.5)': 1,
#   'pos(116.6)': 1,
#   'pos(116.7)': 1,
#   'pos(116.8)': 1,
#   'pos(116.9)': 1,
#   'pos(117.0)': 1,
#   'pos(117.1)': 1,
#   'pos(117.2)': 1,
#   'pos(117.3)': 1,
#   'pos(117.4)': 1,
#   'pos(117.5)': 1,
#   'pos(117.7)': 1,
#   'pos(117.9)': 1,
#   'pos(118.0)': 1,
#   'pos(118.1)': 1,
#   'pos(118.2)': 1,
#   'pos(118.3)': 1,
#   'pos(118.4)': 1,
#   'pos(118.5)': 1,
#   'pos(118.6)': 1,
#   'pos(118.7)': 1,
#   'pos(118.8)': 1,
#   'pos(118.9)': 1,
#   'pos(119.0)': 1,
#   'pos(119.1)': 1,
#   'pos(119.2)': 1,
#   'pos(119.3)': 1,
#   'pos(119.4)': 1,
#   'pos(119.5)': 1,
#   'pos(119.6)': 1,
#   'pos(119.7)': 1,
#   'pos(119.8)': 1,
#   'pos(119.9)': 1,
#   'pos(12.0)': 1,
#   'pos(12.1)': 1,
#   'pos(12.2)': 1,
#   'pos(12.3)': 1,
#   'pos(12.4)': 1,
#   'pos(12.5)': 1,
#   'pos(12.6)': 1,
#   'pos(12.7)': 1,
#   'pos(12.8)': 1,
#   'pos(12.9)': 1,
#   'pos(120.0)': 1,
#   'pos(120.1)': 1,
#   'pos(120.2)': 1,
#   'pos(120.5)': 1,
#   'pos(120.6)': 1,
#   'pos(120.7)': 1,
#   'pos(120.8)': 1,
#   'pos(120.9)': 1,
#   'pos(121.0)': 1,
#   'pos(121.1)': 1,
#   'pos(121.2)': 1,
#   'pos(121.3)': 1,
#   'pos(121.4)': 1,
#   'pos(121.5)': 1,
#   'pos(121.7)': 1,
#   'pos(121.8)': 1,
#   'pos(121.9)': 1,
#   'pos(122.0)': 1,
#   'pos(122.2)': 1,
#   'pos(122.3)': 1,
#   'pos(122.4)': 1,
#   'pos(122.5)': 1,
#   'pos(122.6)': 1,
#   'pos(122.7)': 1,
#   'pos(122.8)': 1,
#   'pos(122.9)': 1,
#   'pos(123.0)': 1,
#   'pos(123.1)': 1,
#   'pos(123.2)': 1,
#   'pos(123.3)': 1,
#   'pos(123.5)': 1,
#   'pos(123.7)': 1,
#   'pos(123.8)': 1,
#   'pos(123.9)': 1,
#   'pos(124.1)': 1,
#   'pos(124.2)': 1,
#   'pos(124.3)': 1,
#   'pos(124.4)': 1,
#   'pos(124.5)': 1,
#   'pos(124.6)': 1,
#   'pos(124.7)': 1,
#   'pos(124.8)': 1,
#   'pos(125.0)': 1,
#   'pos(125.1)': 1,
#   'pos(125.2)': 1,
#   'pos(125.3)': 1,
#   'pos(125.5)': 1,
#   'pos(125.6)': 1,
#   'pos(125.7)': 1,
#   'pos(125.8)': 1,
#   'pos(125.9)': 1,
#   'pos(126.0)': 1,
#   'pos(126.1)': 1,
#   'pos(126.2)': 1,
#   'pos(126.3)': 1,
#   'pos(126.4)': 1,
#   'pos(126.5)': 1,
#   'pos(126.6)': 1,
#   'pos(126.8)': 1,
#   'pos(127.0)': 1,
#   'pos(127.1)': 1,
#   'pos(127.2)': 1,
#   'pos(127.3)': 1,
#   'pos(127.4)': 1,
#   'pos(127.6)': 1,
#   'pos(127.7)': 1,
#   'pos(128.0)': 1,
#   'pos(128.1)': 1,
#   'pos(128.3)': 1,
#   'pos(128.4)': 1,
#   'pos(128.5)': 1,
#   'pos(128.7)': 1,
#   'pos(128.9)': 1,
#   'pos(129.0)': 1,
#   'pos(129.1)': 1,
#   'pos(129.2)': 1,
#   'pos(129.3)': 1,
#   'pos(129.4)': 1,
#   'pos(129.5)': 1,
#   'pos(129.7)': 1,
#   'pos(129.8)': 1,
#   'pos(129.9)': 1,
#   'pos(13.0)': 1,
#   'pos(13.1)': 1,
#   'pos(13.2)': 1,
#   'pos(13.3)': 1,
#   'pos(13.4)': 1,
#   'pos(13.5)': 1,
#   'pos(13.6)': 1,
#   'pos(13.7)': 1,
#   'pos(13.8)': 1,
#   'pos(13.9)': 1,
#   'pos(130.3)': 1,
#   'pos(130.4)': 1,
#   'pos(130.6)': 1,
#   'pos(130.7)': 1,
#   'pos(130.8)': 1,
#   'pos(131.0)': 1,
#   'pos(131.1)': 1,
#   'pos(131.2)': 1,
#   'pos(131.4)': 1,
#   'pos(131.5)': 1,
#   'pos(131.6)': 1,
#   'pos(131.7)': 1,
#   'pos(131.9)': 1,
#   'pos(132.0)': 1,
#   'pos(132.1)': 1,
#   'pos(132.2)': 1,
#   'pos(132.3)': 1,
#   'pos(132.4)': 1,
#   'pos(132.6)': 1,
#   'pos(132.8)': 1,
#   'pos(132.9)': 1,
#   'pos(133.0)': 1,
#   'pos(133.2)': 1,
#   'pos(133.4)': 1,
#   'pos(133.5)': 1,
#   'pos(133.7)': 1,
#   'pos(133.8)': 1,
#   'pos(134.0)': 1,
#   'pos(134.1)': 1,
#   'pos(134.3)': 1,
#   'pos(134.6)': 1,
#   'pos(134.7)': 1,
#   'pos(134.8)': 1,
#   'pos(135.2)': 1,
#   'pos(135.4)': 1,
#   'pos(135.5)': 1,
#   'pos(135.7)': 1,
#   'pos(136.0)': 1,
#   'pos(136.1)': 1,
#   'pos(136.5)': 1,
#   'pos(136.6)': 1,
#   'pos(136.7)': 1,
#   'pos(137.1)': 1,
#   'pos(137.3)': 1,
#   'pos(137.5)': 1,
#   'pos(137.7)': 1,
#   'pos(138.1)': 1,
#   'pos(138.3)': 1,
#   'pos(138.5)': 1,
#   'pos(138.6)': 1,
#   'pos(139.1)': 1,
#   'pos(139.2)': 1,
#   'pos(139.3)': 1,
#   'pos(139.6)': 1,
#   'pos(14.0)': 1,
#   'pos(14.1)': 1,
#   'pos(14.2)': 1,
#   'pos(14.3)': 1,
#   'pos(14.4)': 1,
#   'pos(14.5)': 1,
#   'pos(14.6)': 1,
#   'pos(14.7)': 1,
#   'pos(14.8)': 1,
#   'pos(14.9)': 1,
#   'pos(140.4)': 1,
#   'pos(140.9)': 1,
#   'pos(141.1)': 1,
#   'pos(141.5)': 1,
#   'pos(141.6)': 1,
#   'pos(142.3)': 1,
#   'pos(142.4)': 1,
#   'pos(142.5)': 1,
#   'pos(142.9)': 1,
#   'pos(143.0)': 1,
#   'pos(143.1)': 1,
#   'pos(143.2)': 1,
#   'pos(143.7)': 1,
#   'pos(144.1)': 1,
#   'pos(144.9)': 1,
#   'pos(145.5)': 1,
#   'pos(146.6)': 1,
#   'pos(147.1)': 1,
#   'pos(147.8)': 1,
#   'pos(148.2)': 1,
#   'pos(149.8)': 1,
#   'pos(15.0)': 1,
#   'pos(15.1)': 1,
#   'pos(15.2)': 1,
#   'pos(15.3)': 1,
#   'pos(15.4)': 1,
#   'pos(15.5)': 1,
#   'pos(15.6)': 1,
#   'pos(15.7)': 1,
#   'pos(15.8)': 1,
#   'pos(15.9)': 1,
#   'pos(150.6)': 1,
#   'pos(150.8)': 1,
#   'pos(151.3)': 1,
#   'pos(151.4)': 1,
#   'pos(151.6)': 1,
#   'pos(152.9)': 1,
#   'pos(153.7)': 1,
#   'pos(158.2)': 1,
#   'pos(159.3)': 1,
#   'pos(159.8)': 1,
#   'pos(16.0)': 1,
#   'pos(16.1)': 1,
#   'pos(16.2)': 1,
#   'pos(16.3)': 1,
#   'pos(16.4)': 1,
#   'pos(16.5)': 1,
#   'pos(16.6)': 1,
#   'pos(16.7)': 1,
#   'pos(16.8)': 1,
#   'pos(16.9)': 1,
#   'pos(161.6)': 1,
#   'pos(163.6)': 1,
#   'pos(169.4)': 1,
#   'pos(169.6)': 1,
#   'pos(17.0)': 1,
#   'pos(17.1)': 1,
#   'pos(17.2)': 1,
#   'pos(17.3)': 1,
#   'pos(17.4)': 1,
#   'pos(17.6)': 1,
#   'pos(17.7)': 1,
#   'pos(17.8)': 1,
#   'pos(17.9)': 1,
#   'pos(170.5)': 1,
#   'pos(171.9)': 1,
#   'pos(18.0)': 1,
#   'pos(18.1)': 1,
#   'pos(18.2)': 1,
#   'pos(18.4)': 1,
#   'pos(18.5)': 1,
#   'pos(18.6)': 1,
#   'pos(18.7)': 1,
#   'pos(18.8)': 1,
#   'pos(19.1)': 1,
#   'pos(19.2)': 1,
#   'pos(19.3)': 1,
#   'pos(19.4)': 1,
#   'pos(19.6)': 1,
#   'pos(19.7)': 1,
#   'pos(19.8)': 1,
#   'pos(19.9)': 1,
#   'pos(20.0)': 1,
#   'pos(20.2)': 1,
#   'pos(20.3)': 1,
#   'pos(20.4)': 1,
#   'pos(20.5)': 1,
#   'pos(20.6)': 1,
#   'pos(20.7)': 1,
#   'pos(21.0)': 1,
#   'pos(21.1)': 1,
#   'pos(21.2)': 1,
#   'pos(21.3)': 1,
#   'pos(21.5)': 1,
#   'pos(21.6)': 1,
#   'pos(22.5)': 1,
#   'pos(22.6)': 1,
#   'pos(22.8)': 1,
#   'pos(23.0)': 1,
#   'pos(23.4)': 1,
#   'pos(23.7)': 1,
#   'pos(23.9)': 1,
#   'pos(26.0)': 1,
#   'pos(27.3)': 1,
#   'pos(28.5)': 1,
#   'pos(>1000)': 1320,
#   'positive': 102},
#  'CHNS4RR': {'negative': 9},
#  'CI09DEE': {'bm°á°úâüá¶': 4, '°ñ¼öæçµ¶°á°ú âüá¶': 3},
#  'CK8LJXR': {'negative': 141, 'positive': 1},
#  'DBDGMXX': {'neg': 4, 'neg   -': 1, 'neg  -': 686, 'neg -': 10, 'pos  +': 32},
#  'DNDA5TR': {'negative': 2, 'º°áöâüá¶': 1},
#  'DOHW1IF': {'negative': 3},
#  'DU5QS2O': {'negative': 123},
#  'DVEBVZ4': {'negative': 2},
#  'DXRHN1Q': {'negative': 5},
#  'ECBQ7XK': {'+': 1328,
#   '++': 208,
#   '+++': 178,
#   'neg   -': 7,
#   'neg  -': 41216,
#   'neg -': 16},
#  'EJ01JWT': {'negative': 27, 'positive': 2},
#  'EKMTHZ4': {'negative': 31},
#  'EMY6F02': {'negative': 42, 'positive': 1},
#  'ERY2G6Y': {'negative': 1},
#  'ESWF9EN': {'negative': 13},
#  'EWVQOBT': {'negative': 1},
#  'F323BOX': {'neg': 60},
#  'F3L3RC8': {'negative': 3},
#  'F3ZA50C': {'neg(1.01)': 7,
#   'neg(1.02)': 8,
#   'neg(1.03)': 8,
#   'neg(1.04)': 10,
#   'neg(1.05)': 9,
#   'neg(1.06)': 10,
#   'neg(1.07)': 10,
#   'neg(1.08)': 10,
#   'neg(1.09)': 11,
#   'neg(1.10)': 12,
#   'neg(1.11)': 12,
#   'neg(1.12)': 12,
#   'neg(1.13)': 12,
#   'neg(1.14)': 13,
#   'neg(1.15)': 13,
#   'neg(1.16)': 12,
#   'neg(1.17)': 12,
#   'neg(1.18)': 12,
#   'neg(1.19)': 12,
#   'neg(1.20)': 11,
#   'neg(1.21)': 12,
#   'neg(1.22)': 11,
#   'neg(1.23)': 11,
#   'neg(1.24)': 10,
#   'neg(1.25)': 10,
#   'neg(1.26)': 9,
#   'neg(1.27)': 9,
#   'neg(1.28)': 8,
#   'neg(1.29)': 8,
#   'neg(1.30)': 7,
#   'neg(1.31)': 7,
#   'neg(1.32)': 7,
#   'neg(1.33)': 6,
#   'neg(1.34)': 7,
#   'neg(1.35)': 6,
#   'neg(1.36)': 6,
#   'neg(1.37)': 6,
#   'neg(1.38)': 6,
#   'neg(1.39)': 6,
#   'neg(1.40)': 6,
#   'neg(1.41)': 5,
#   'neg(1.42)': 5,
#   'neg(1.43)': 5,
#   'neg(1.44)': 6,
#   'neg(1.45)': 5,
#   'neg(1.46)': 5,
#   'neg(1.47)': 5,
#   'neg(1.48)': 5,
#   'neg(1.49)': 6,
#   'neg(1.50)': 6,
#   'neg(1.51)': 6,
#   'neg(1.52)': 5,
#   'neg(1.53)': 6,
#   'neg(1.54)': 5,
#   'neg(1.55)': 5,
#   'neg(1.56)': 5,
#   'neg(1.57)': 5,
#   'neg(1.58)': 5,
#   'neg(1.59)': 5,
#   'neg(1.60)': 5,
#   'neg(1.61)': 5,
#   'neg(1.62)': 5,
#   'neg(1.63)': 5,
#   'neg(1.64)': 4,
#   'neg(1.65)': 4,
#   'neg(1.66)': 4,
#   'neg(1.67)': 4,
#   'neg(1.68)': 4,
#   'neg(1.69)': 4,
#   'neg(1.70)': 4,
#   'neg(1.71)': 4,
#   'neg(1.72)': 4,
#   'neg(1.73)': 3,
#   'neg(1.74)': 3,
#   'neg(1.75)': 3,
#   'neg(1.76)': 3,
#   'neg(1.77)': 2,
#   'neg(1.78)': 3,
#   'neg(1.79)': 3,
#   'neg(1.80)': 3,
#   'neg(1.81)': 2,
#   'neg(1.82)': 2,
#   'neg(1.83)': 2,
#   'neg(1.84)': 2,
#   'neg(1.85)': 2,
#   'neg(1.86)': 2,
#   'neg(1.87)': 2,
#   'neg(1.88)': 1,
#   'neg(1.89)': 2,
#   'neg(1.90)': 2,
#   'neg(1.91)': 2,
#   'neg(1.92)': 2,
#   'neg(1.93)': 1,
#   'neg(1.94)': 1,
#   'neg(1.95)': 1,
#   'neg(1.96)': 1,
#   'neg(1.97)': 1,
#   'neg(1.98)': 1,
#   'neg(1.99)': 1,
#   'neg(2.00)': 1,
#   'neg(2.01)': 1,
#   'neg(2.02)': 1,
#   'neg(2.03)': 1,
#   'neg(2.04)': 1,
#   'neg(2.05)': 1,
#   'neg(2.06)': 1,
#   'neg(2.07)': 1,
#   'neg(2.08)': 1,
#   'neg(2.09)': 1,
#   'neg(2.10)': 1,
#   'neg(2.11)': 1,
#   'neg(2.12)': 1,
#   'negative': 278,
#   'pos(0.001)': 14,
#   'pos(0.002)': 132,
#   'pos(0.003)': 90,
#   'pos(0.004)': 98,
#   'pos(0.005)': 34,
#   'pos(0.006)': 14,
#   'pos(0.007)': 9,
#   'pos(0.008)': 7,
#   'pos(0.009)': 6,
#   'pos(0.01)': 70,
#   'pos(0.010)': 5,
#   'pos(0.011)': 5,
#   'pos(0.012)': 4,
#   'pos(0.013)': 3,
#   'pos(0.014)': 3,
#   'pos(0.015)': 3,
#   'pos(0.016)': 2,
#   'pos(0.017)': 2,
#   'pos(0.018)': 2,
#   'pos(0.019)': 1,
#   'pos(0.02)': 91,
#   'pos(0.020)': 2,
#   'pos(0.021)': 1,
#   'pos(0.022)': 1,
#   'pos(0.023)': 1,
#   'pos(0.024)': 1,
#   'pos(0.025)': 1,
#   'pos(0.026)': 1,
#   'pos(0.027)': 1,
#   'pos(0.028)': 1,
#   'pos(0.029)': 1,
#   'pos(0.03)': 43,
#   'pos(0.030)': 1,
#   'pos(0.031)': 1,
#   'pos(0.032)': 1,
#   'pos(0.033)': 1,
#   'pos(0.034)': 1,
#   'pos(0.035)': 1,
#   'pos(0.036)': 1,
#   'pos(0.037)': 1,
#   'pos(0.038)': 1,
#   'pos(0.039)': 1,
#   'pos(0.04)': 14,
#   'pos(0.040)': 1,
#   'pos(0.041)': 1,
#   'pos(0.042)': 1,
#   'pos(0.043)': 1,
#   'pos(0.044)': 1,
#   'pos(0.045)': 1,
#   'pos(0.046)': 1,
#   'pos(0.047)': 1,
#   'pos(0.048)': 1,
#   'pos(0.049)': 1,
#   'pos(0.05)': 8,
#   'pos(0.050)': 1,
#   'pos(0.051)': 1,
#   'pos(0.052)': 1,
#   'pos(0.053)': 1,
#   'pos(0.054)': 1,
#   'pos(0.055)': 2,
#   'pos(0.056)': 1,
#   'pos(0.057)': 2,
#   'pos(0.058)': 1,
#   'pos(0.059)': 1,
#   'pos(0.06)': 6,
#   'pos(0.060)': 2,
#   'pos(0.061)': 2,
#   'pos(0.062)': 1,
#   'pos(0.063)': 2,
#   'pos(0.064)': 1,
#   'pos(0.065)': 1,
#   'pos(0.066)': 1,
#   'pos(0.067)': 1,
#   'pos(0.068)': 1,
#   'pos(0.069)': 1,
#   'pos(0.07)': 4,
#   'pos(0.070)': 1,
#   'pos(0.071)': 1,
#   'pos(0.072)': 2,
#   'pos(0.073)': 1,
#   'pos(0.074)': 1,
#   'pos(0.075)': 1,
#   'pos(0.076)': 1,
#   'pos(0.077)': 1,
#   'pos(0.078)': 1,
#   'pos(0.079)': 1,
#   'pos(0.08)': 3,
#   'pos(0.080)': 1,
#   'pos(0.081)': 1,
#   'pos(0.082)': 1,
#   'pos(0.083)': 1,
#   'pos(0.084)': 1,
#   'pos(0.085)': 1,
#   'pos(0.086)': 1,
#   'pos(0.087)': 1,
#   'pos(0.088)': 1,
#   'pos(0.089)': 1,
#   'pos(0.09)': 3,
#   'pos(0.090)': 1,
#   'pos(0.091)': 1,
#   'pos(0.092)': 1,
#   'pos(0.094)': 1,
#   'pos(0.096)': 1,
#   'pos(0.097)': 1,
#   'pos(0.099)': 1,
#   'pos(0.10)': 2,
#   'pos(0.102)': 1,
#   'pos(0.11)': 2,
#   'pos(0.12)': 2,
#   'pos(0.13)': 2,
#   'pos(0.14)': 1,
#   'pos(0.15)': 1,
#   'pos(0.16)': 1,
#   'pos(0.17)': 1,
#   'pos(0.18)': 1,
#   'pos(0.19)': 1,
#   'pos(0.20)': 1,
#   'pos(0.21)': 1,
#   'pos(0.22)': 1,
#   'pos(0.23)': 1,
#   'pos(0.24)': 1,
#   'pos(0.25)': 1,
#   'pos(0.27)': 1,
#   'pos(0.29)': 1,
#   'pos(0.30)': 1,
#   'pos(0.32)': 1,
#   'pos(0.33)': 1,
#   'pos(0.73)': 1,
#   'pos(0.93)': 1,
#   'pos(0.948)': 1,
#   'pos(0.97)': 1,
#   'pos(0.975)': 1,
#   'pos(0.978)': 1,
#   'pos(0.98)': 1,
#   'pos(0.982)': 1,
#   'pos(0.984)': 1,
#   'pos(0.986)': 1,
#   'pos(0.993)': 1,
#   'pos(0.994)': 1,
#   'pos(0.995)': 1,
#   'pos(0.996)': 1,
#   'pos(0.999)': 1,
#   'pos(1.00)': 6,
#   'positive': 4},
#  'F6H82ZW': {'negative': 13},
#  'F7Y216N': {'negative': 400, 'pos(60.00)': 7, 'positive': 2308},
#  'F8VMUZ1': {'negative': 4},
#  'FEA29VE': {'+': 5110,
#   '++': 2892,
#   '+++': 1859,
#   '++++': 2962,
#   '10    tr': 1,
#   '10   tr': 5370,
#   '10  tr': 526,
#   '10 tr': 2,
#   'neg   -': 2,
#   'neg  -': 24207,
#   'neg -': 10},
#  'FL486Z0': {'0.01(neg)': 2,
#   '0.02(neg)': 4,
#   '0.03(neg)': 3,
#   '0.04(neg)': 1,
#   'borderline': 1,
#   'negative': 82,
#   'positive': 4},
#  'FLJNK5R': {'negative': 9},
#  'FM7QV1J': {'negative': 44,
#   'positive': 3,
#   'positive(+)': 1,
#   'positive(++)': 1,
#   'w-positive': 2},
#  'FO9BV0M': {'negative(<1.0)': 1},
#  'FPX3ZTC': {'neg': 1, 'negative': 368, 'positive': 28},
#  'FUSNTPV': {'<0.35(0)': 1},
#  'FW6U2M4': {'negative': 142},
#  'FYGZ834': {'negative': 3},
#  'G0O42XJ': {'negative': 19},
#  'G1YKMKH': {'negative': 19},
#  'G25YNR0': {'+': 93,
#   '++': 56,
#   '+++': 51,
#   '++++': 127,
#   '10   tr': 103,
#   '10  tr': 1,
#   '10 tr': 2,
#   'neg': 1,
#   'neg  -': 289,
#   'neg -': 4},
#  'GB1REGO': {'negative': 19},
#  'GJAK6EG': {'bm°á°úâüá¶': 5, '°ñ¼öæçµ¶°á°ú âüá¶': 3},
#  'GMWI0IQ': {'negative': 1},
#  'GRYWOGL': {'negative': 28, 'positive': 6},
#  'GSRPYL5': {'negative': 48, 'positive': 2},
#  'GT8WHVU': {'negative': 4642, 'positive': 2},
#  'H0BVIM3': {'negative': 31},
#  'H683IGL': {'negative': 27},
#  'H70LOEW': {'negative': 18},
#  'HHEC8FN': {'+': 34,
#   '++': 15,
#   '+++': 40,
#   '50   tr': 38,
#   'norm': 2,
#   'norm  -': 1,
#   'norm -': 597},
#  'HOTRTQE': {'negative': 198},
#  'HUX15VT': {'negative': 7},
#  'I196X1T': {'negative': 7},
#  'I9IOBJH': {'negative': 198},
#  'IHVV167': {'+': 155,
#   '++': 55,
#   '+++': 45,
#   'neg': 2,
#   'neg  -': 465,
#   'neg -': 6},
#  'IIYAMW6': {'neg': 3},
#  'IJ8B1Y1': {'negative': 244,
#   'po 1.0': 1,
#   'po 1.1': 3,
#   'po 1.2': 2,
#   'po 1.3': 2,
#   'po 1.4': 1,
#   'po 1.5': 1,
#   'po 1.6': 1,
#   'po 1.7': 1,
#   'po 1.8': 1,
#   'po 1.9': 1,
#   'po 2.0': 1,
#   'po 2.1': 1,
#   'po 2.4': 1,
#   'positive': 79},
#  'IKZMJJY': {'negative': 85,
#   'po 1.0': 2,
#   'po 2.0': 1,
#   'po 2.1': 1,
#   'po 2.4': 1,
#   'po 2.7': 1},
#  'IOBE5S5': {'non-rea(c)': 4,
#   'non-react': 147,
#   'non-reactive': 80,
#   'non-reactive(csf)': 2,
#   'react(1:1)': 2,
#   'react(1:2)': 1,
#   'w-rea(1:1)': 3,
#   'w-react': 1,
#   'weakly-reactive(1:1)': 1},
#  'IPZAJPC': {'0.00(neg)': 1,
#   '0.01(neg)': 4,
#   '0.02(neg)': 3,
#   '0.03(neg)': 2,
#   '0.04(neg)': 1},
#  'IU323QA': {'negative': 4, 'pos(4)': 1},
#  'IX5T2JA': {'neg': 2},
#  'IZF34RB': {'negative': 19, 'positive': 8},
#  'J0O5DK7': {'negative': 327},
#  'J245ZVA': {'negative': 2},
#  'J2OHUGX': {'negative': 495,
#   'pos(8.00)': 13,
#   'pos(>120)': 84,
#   'pos(>120.0)': 1,
#   'positive': 167,
#   'positive (>8.0)': 1},
#  'JF15ID0': {'negative': 19},
#  'JKK1FFN': {'positive (>300.0)': 3},
#  'JLDJ2IR': {'negative': 7},
#  'JO3FJG7': {'negative': 7},
#  'JPO7D53': {'negative': 11},
#  'JR58LKI': {'negative': 75},
#  'K3T6XK8': {'negative': 7},
#  'K7FBA3W': {'negative': 2},
#  'K9X30ZH': {'negative': 5},
#  'KDA9N9L': {'negative': 7},
#  'KHC0VI7': {'negative': 2},
#  'KHCNF8V': {'negative': 7},
#  'KJ164KA': {'negative': 5, 'positive': 10},
#  'KOD5BXK': {'bm°á°úâüá¶': 5, '°ñ¼öæçµ¶°á°ú âüá¶': 6},
#  'KVFJUO8': {'negative': 38},
#  'KXD1LMR': {'negative': 4},
#  'KYB4X8L': {'negative': 9},
#  'L1B8XKH': {'negative': 9},
#  'L2179VA': {'non-rea(c)': 1,
#   'non-react': 19,
#   'non-reactive': 4,
#   'reactive': 10},
#  'L51N3Q2': {'negative': 20},
#  'L6P2S6T': {'negative': 10},
#  'L6PNC22': {'negative': 61, 'pos(p-type': 1},
#  'L6U9UVI': {'negative': 5},
#  'LBUEQZ7': {'negative': 9},
#  'LN64GAW': {'negative': 24, 'positive': 2},
#  'LRR2HM7': {'negative': 152,
#   'non-rea(c)': 2,
#   'non-react': 1142,
#   'non-reactive': 666,
#   'non-reactive(0.1)': 3,
#   'non-reactive(csf)': 1,
#   'positive': 9,
#   'reactive': 55,
#   'w-react': 12,
#   'w-reactive': 3,
#   'weakly-reactive': 4},
#  'LTGK20G': {'negative': 16},
#  'LVVKW6S': {'negative': 9},
#  'LX88DGI': {'negative': 7},
#  'M19N4FE': {'º°áöâüá¶': 9},
#  'MCCBNC2': {'negative': 9},
#  'ML5A24Z': {'negative': 5},
#  'MNOJI01': {'negative': 9},
#  'N09GJW4': {'equivocal': 2, 'negative': 65},
#  'N0HECNI': {'negative': 6, 'º°áöâüá¶': 2},
#  'N42U3HA': {'neg': 4, 'neg -': 2, 'negative': 8, 'pos': 1, 'positive': 2},
#  'N5NQ1J6': {'negative': 19},
#  'N8CCI5P': {'negative': 114},
#  'NA1K22H': {'0.00(neg)': 4,
#   '0.01(neg)': 16,
#   '0.02(neg)': 27,
#   '0.03(neg)': 17,
#   '0.04(neg)': 8,
#   '0.05(neg)': 4,
#   '0.06(neg)': 2,
#   '0.07(neg)': 2,
#   '0.08(neg)': 1,
#   '0.09(neg)': 1,
#   '0.10(neg)': 1,
#   '0.11(neg)': 1,
#   'borderline': 4,
#   'negative': 158,
#   'positive': 10},
#  'NLV7OAH': {'negative': 1},
#  'NLYSR2T': {'negative': 7},
#  'NOVX9KF': {'negative': 7},
#  'NTBQDEI': {'neg(1:160)': 1, 'negative': 47, 'pos(1:320)': 1},
#  'NTLFAEI': {'negative': 1},
#  'NY2B0AI': {'negative': 220,
#   'pos(1:160)': 4,
#   'pos(1:320)': 4,
#   'pos(1:40)': 9,
#   'pos(1:80)': 6,
#   'pos(>1:320': 3,
#   'positive(1:1280)': 3,
#   'positive(1:160)': 45,
#   'positive(1:2560)': 1,
#   'positive(1:320)': 46,
#   'positive(1:40)': 86,
#   'positive(1:5120)': 1,
#   'positive(1:640)': 5,
#   'positive(1:80)': 65,
#   'positive(>1:1280)': 2,
#   'positive(>1:320)': 1},
#  'O1WYAEI': {'negative': 327},
#  'O287ZZZ': {'negative': 7},
#  'O8SW0VM': {'negative': 24},
#  'OEGDK9V': {'negative': 98},
#  'OF7MNCI': {'negative': 4},
#  'OH3JWNX': {'0.00(0)': 2, '0.01(0)': 2, '0.02(0)': 1, '<0.35(0)': 2},
#  'OJ4GMT3': {'negative': 19},
#  'OY98D89': {'negative': 6},
#  'P3SSYS7': {'negative': 117},
#  'P4R9HTG': {'negative': 7},
#  'P7Z6WDP': {'negative': 2},
#  'P97N39H': {'negative': 4},
#  'PAS3RX9': {'negative': 40, 'positive': 2},
#  'PJD3J9E': {'negative': 19},
#  'PKVOWU2': {'negative': 6},
#  'PM4LVGW': {'negative': 2},
#  'PTKKXA0': {'negative': 19},
#  'PUQO0AD': {'neg': 30, 'negative': 282},
#  'PWDTJ7F': {'neg(0.11)': 1,
#   'neg(0.12)': 3,
#   'neg(0.13)': 7,
#   'neg(0.14)': 13,
#   'neg(0.15)': 22,
#   'neg(0.16)': 31,
#   'neg(0.17)': 40,
#   'neg(0.18)': 55,
#   'neg(0.19)': 71,
#   'neg(0.20)': 85,
#   'neg(0.21)': 102,
#   'neg(0.22)': 111,
#   'neg(0.23)': 111,
#   'neg(0.24)': 110,
#   'neg(0.25)': 109,
#   'neg(0.26)': 102,
#   'neg(0.27)': 93,
#   'neg(0.28)': 89,
#   'neg(0.29)': 80,
#   'neg(0.30)': 70,
#   'neg(0.31)': 65,
#   'neg(0.32)': 58,
#   'neg(0.33)': 51,
#   'neg(0.34)': 46,
#   'neg(0.35)': 41,
#   'neg(0.36)': 36,
#   'neg(0.37)': 32,
#   'neg(0.38)': 28,
#   'neg(0.39)': 25,
#   'neg(0.40)': 22,
#   'neg(0.41)': 19,
#   'neg(0.42)': 17,
#   'neg(0.43)': 15,
#   'neg(0.44)': 13,
#   'neg(0.45)': 12,
#   'neg(0.46)': 11,
#   'neg(0.47)': 9,
#   'neg(0.48)': 9,
#   'neg(0.49)': 8,
#   'neg(0.50)': 7,
#   'neg(0.51)': 6,
#   'neg(0.52)': 5,
#   'neg(0.53)': 4,
#   'neg(0.54)': 4,
#   'neg(0.55)': 3,
#   'neg(0.56)': 3,
#   'neg(0.57)': 3,
#   'neg(0.58)': 2,
#   'neg(0.59)': 2,
#   'neg(0.60)': 2,
#   'neg(0.61)': 2,
#   'neg(0.62)': 1,
#   'neg(0.63)': 1,
#   'neg(0.64)': 1,
#   'neg(0.65)': 1,
#   'neg(0.66)': 1,
#   'neg(0.67)': 1,
#   'neg(0.68)': 1,
#   'neg(0.69)': 1,
#   'neg(0.70)': 1,
#   'neg(0.71)': 1,
#   'negative': 10317,
#   'pos(>250 iu/ml)': 20,
#   'pos(>250)': 8,
#   'positive': 13},
#  'Q14DXJ1': {'<10': 3, '>100': 5, 'negative': 22, 'positive(>100)': 4},
#  'Q2IRAY4': {'negative': 1},
#  'QH7AYEI': {'bm°á°úâüá¶': 8, '°ñ¼öæçµ¶°á°ú âüá¶': 6},
#  'QL3QDVM': {'negative': 2},
#  'QMBPPK6': {'negative': 5},
#  'QMY06NG': {'neg': 27},
#  'QT0EK87': {'negative': 2},
#  'QV6KTAC': {'negative': 1},
#  'QWK9ZKD': {'+': 505,
#   '++': 160,
#   '+++': 49,
#   '1    tr': 876,
#   '1  tr': 737,
#   'neg  -': 1,
#   'norm  -': 5272,
#   'norm -': 35351},
#  'QWX6Q6Y': {'negative': 3},
#  'QZBYXVC': {'negative': 9},
#  'R3MTDK4': {'bm°á°úâüá¶': 8, '°ñ¼öæçµ¶°á°ú âüá¶': 6},
#  'R4W8OH0': {'negative': 2527,
#   'po 1.0': 26,
#   'po 1.1': 55,
#   'po 1.2': 50,
#   'po 1.3': 45,
#   'po 1.4': 41,
#   'po 1.5': 37,
#   'po 1.6': 35,
# ...
#   'po 16.1': 3,
#   'po 16.2': 4,
#   'po 16.3': 4,
#   'po 16.4': 3,
#   'po 16.5': 3,
#   'po 16.6': 3,
#   'po 16.7': 4,
#   'po 16.8': 3,
#   'po 16.9': 4,
#   'po 17.0': 3,
#   'po 17.1': 3,
#   'po 17.2': 3,
#   'po 17.3': 4,
#   'po 17.4': 3,
#   'po 17.5': 3,
#   'po 17.6': 3,
#   'po 17.7': 3,
#   'po 17.8': 3,
#   'po 17.9': 3,
#   'po 18.0': 3,
#   'po 18.1': 3,
#   'po 18.2': 3,
#   'po 18.3': 3,
#   'po 18.4': 3,
#   'po 18.5': 3,
#   'po 18.6': 3,
#   'po 18.7': 3,
#   'po 18.8': 3,
#   'po 18.9': 3,
#   'po 19.0': 3,
#   'po 19.1': 3,
#   'po 19.2': 2,
#   'po 19.3': 3,
#   'po 19.4': 3,
#   'po 19.5': 3,
#   'po 19.6': 3,
#   'po 19.7': 3,
#   'po 19.8': 3,
#   'po 19.9': 2,
#   'po 2.0': 27,
#   'po 2.1': 26,
#   'po 2.2': 25,
#   'po 2.3': 25,
#   'po 2.4': 23,
#   'po 2.5': 22,
#   'po 2.6': 22,
#   'po 2.7': 22,
#   'po 2.8': 21,
#   'po 2.9': 21,
#   'po 20.0': 3,
#   'po 20.1': 3,
#   'po 20.2': 3,
#   'po 20.3': 2,
#   'po 20.4': 2,
#   'po 20.5': 3,
#   'po 20.6': 2,
#   'po 20.7': 3,
#   'po 20.8': 3,
#   'po 20.9': 2,
#   'po 21.0': 2,
#   'po 21.1': 2,
#   'po 21.2': 2,
#   'po 21.3': 2,
#   'po 21.4': 2,
#   'po 21.5': 2,
#   'po 21.6': 2,
#   'po 21.7': 2,
#   'po 21.8': 2,
#   'po 21.9': 2,
#   'po 22.0': 2,
#   'po 22.1': 2,
#   'po 22.2': 2,
#   'po 22.3': 2,
#   'po 22.4': 2,
#   'po 22.5': 2,
#   'po 22.6': 2,
#   'po 22.7': 2,
#   'po 22.8': 2,
#   'po 22.9': 2,
#   'po 23.0': 2,
#   'po 23.1': 2,
#   'po 23.2': 2,
#   'po 23.3': 2,
#   'po 23.4': 2,
#   'po 23.5': 2,
#   'po 23.6': 2,
#   'po 23.7': 2,
#   'po 23.8': 2,
#   'po 23.9': 2,
#   'po 24.0': 2,
#   'po 24.1': 2,
#   'po 24.2': 2,
#   'po 24.3': 2,
#   'po 24.4': 2,
#   'po 24.5': 2,
#   'po 24.6': 2,
#   'po 24.7': 2,
#   'po 24.8': 2,
#   'po 24.9': 2,
#   'po 25.0': 2,
#   'po 25.1': 2,
#   'po 25.2': 2,
#   'po 25.3': 2,
#   'po 25.4': 2,
#   'po 25.5': 2,
#   'po 25.6': 2,
#   'po 25.7': 2,
#   'po 25.8': 2,
#   'po 25.9': 1,
#   'po 26.0': 2,
#   'po 26.1': 1,
#   'po 26.2': 1,
#   'po 26.3': 2,
#   'po 26.4': 1,
#   'po 26.5': 2,
#   'po 26.6': 2,
#   'po 26.7': 2,
#   'po 26.8': 1,
#   'po 26.9': 1,
#   'po 27.0': 2,
#   'po 27.1': 1,
#   'po 27.2': 2,
#   'po 27.3': 2,
#   'po 27.4': 1,
#   'po 27.5': 1,
#   'po 27.6': 1,
#   'po 27.7': 1,
#   'po 27.8': 2,
#   'po 27.9': 1,
#   'po 28.0': 1,
#   'po 28.1': 1,
#   'po 28.2': 2,
#   'po 28.3': 1,
#   'po 28.4': 2,
#   'po 28.5': 1,
#   'po 28.6': 2,
#   'po 28.7': 1,
#   'po 28.8': 1,
#   'po 28.9': 1,
#   'po 29.0': 1,
#   'po 29.1': 1,
#   'po 29.2': 1,
#   'po 29.3': 1,
#   'po 29.4': 1,
#   'po 29.5': 1,
#   'po 29.6': 1,
#   'po 29.7': 1,
#   'po 29.8': 1,
#   'po 29.9': 1,
#   'po 3.0': 20,
#   'po 3.1': 19,
#   'po 3.2': 19,
#   'po 3.3': 19,
#   'po 3.4': 18,
#   'po 3.5': 17,
#   'po 3.6': 17,
#   'po 3.7': 17,
#   'po 3.8': 16,
#   'po 3.9': 16,
#   'po 30.0': 1,
#   'po 30.1': 1,
#   'po 30.2': 2,
#   'po 30.3': 1,
#   'po 30.4': 1,
#   'po 30.5': 1,
#   'po 30.6': 1,
#   'po 30.7': 1,
#   'po 30.8': 1,
#   'po 30.9': 1,
#   'po 31.0': 1,
#   'po 31.1': 1,
#   'po 31.2': 1,
#   'po 31.3': 1,
#   'po 31.4': 1,
#   'po 31.5': 1,
#   'po 31.6': 1,
#   'po 31.7': 1,
#   'po 31.8': 1,
#   'po 31.9': 1,
#   'po 32.0': 1,
#   'po 32.1': 1,
#   'po 32.2': 1,
#   'po 32.3': 1,
#   'po 32.4': 1,
#   'po 32.5': 1,
#   'po 32.6': 1,
#   'po 32.7': 1,
#   'po 32.8': 1,
#   'po 32.9': 1,
#   'po 33.0': 1,
#   'po 33.1': 1,
#   'po 33.2': 1,
#   'po 33.3': 1,
#   'po 33.4': 1,
#   'po 33.5': 1,
#   'po 33.6': 1,
#   'po 33.7': 1,
#   'po 33.8': 1,
#   'po 33.9': 1,
#   'po 34.0': 1,
#   'po 34.1': 1,
#   'po 34.2': 1,
#   'po 34.3': 1,
#   'po 34.4': 1,
#   'po 34.5': 1,
#   'po 34.6': 1,
#   'po 34.7': 1,
#   'po 34.8': 1,
#   'po 34.9': 1,
#   'po 35.0': 1,
#   'po 35.1': 1,
#   'po 35.2': 1,
#   'po 35.3': 1,
#   'po 35.4': 1,
#   'po 35.5': 1,
#   'po 35.6': 1,
#   'po 35.7': 1,
#   'po 35.8': 1,
#   'po 35.9': 1,
#   'po 36.0': 1,
#   'po 36.1': 1,
#   'po 36.2': 1,
#   'po 36.3': 1,
#   'po 36.4': 1,
#   'po 36.5': 1,
#   'po 36.6': 1,
#   'po 36.7': 1,
#   'po 36.8': 1,
#   'po 36.9': 1,
#   'po 37.0': 1,
#   'po 37.1': 1,
#   'po 37.2': 1,
#   'po 37.3': 1,
#   'po 37.4': 1,
#   'po 37.5': 1,
#   'po 37.6': 1,
#   'po 37.7': 1,
#   'po 37.8': 1,
#   'po 38.1': 1,
#   'po 38.2': 1,
#   'po 38.3': 1,
#   'po 38.4': 1,
#   'po 38.5': 1,
#   'po 38.6': 1,
#   'po 38.8': 1,
#   'po 38.9': 1,
#   'po 39.0': 1,
#   'po 39.1': 1,
#   'po 39.2': 1,
#   'po 39.3': 1,
#   'po 39.4': 1,
#   'po 39.5': 1,
#   'po 39.6': 1,
#   'po 39.7': 1,
#   'po 39.8': 1,
#   'po 39.9': 1,
#   'po 4.0': 16,
#   'po 4.1': 15,
#   'po 4.2': 15,
#   'po 4.3': 14,
#   'po 4.4': 14,
#   'po 4.5': 14,
#   'po 4.6': 15,
#   'po 4.7': 15,
#   'po 4.8': 13,
#   'po 4.9': 13,
#   'po 40.0': 1,
#   'po 40.1': 1,
#   'po 40.2': 1,
#   'po 40.3': 1,
#   'po 40.4': 1,
#   'po 40.5': 1,
#   'po 40.6': 1,
#   'po 40.7': 1,
#   'po 40.9': 1,
#   'po 41.0': 1,
#   'po 41.1': 1,
#   'po 41.2': 1,
#   'po 41.3': 1,
#   'po 41.4': 1,
#   'po 41.5': 1,
#   'po 41.6': 1,
#   'po 41.7': 1,
#   'po 41.8': 1,
#   'po 42.0': 1,
#   'po 42.2': 1,
#   'po 42.3': 1,
#   'po 42.5': 1,
#   'po 42.6': 1,
#   'po 42.7': 1,
#   'po 42.9': 1,
#   'po 43.1': 1,
#   'po 43.3': 1,
#   'po 43.4': 1,
#   'po 43.5': 1,
#   'po 43.8': 1,
#   'po 44.0': 1,
#   'po 44.1': 1,
#   'po 45.0': 1,
#   'po 45.3': 1,
#   'po 45.5': 1,
#   'po 45.7': 1,
#   'po 45.8': 1,
#   'po 46.6': 1,
#   'po 47.2': 1,
#   'po 47.3': 1,
#   'po 47.4': 1,
#   'po 5.0': 14,
#   'po 5.1': 13,
#   'po 5.2': 13,
#   'po 5.3': 13,
#   'po 5.4': 13,
#   'po 5.5': 12,
#   'po 5.6': 11,
#   'po 5.7': 12,
#   'po 5.8': 11,
#   'po 5.9': 12,
#   'po 51.7': 1,
#   'po 6.0': 12,
#   'po 6.1': 11,
#   'po 6.2': 11,
#   'po 6.3': 11,
#   'po 6.4': 10,
#   'po 6.5': 10,
#   'po 6.6': 10,
#   'po 6.7': 10,
#   'po 6.8': 10,
#   'po 6.9': 10,
#   'po 7.0': 9,
#   'po 7.1': 9,
#   'po 7.2': 10,
#   'po 7.3': 9,
#   'po 7.4': 9,
#   'po 7.5': 9,
#   'po 7.6': 9,
#   'po 7.7': 9,
#   'po 7.8': 9,
#   'po 7.9': 8,
#   'po 8.0': 8,
#   'po 8.1': 9,
#   'po 8.2': 9,
#   'po 8.3': 9,
#   'po 8.4': 8,
#   'po 8.5': 8,
#   'po 8.6': 8,
#   'po 8.7': 8,
#   'po 8.8': 8,
#   'po 8.9': 8,
#   'po 9.0': 7,
#   'po 9.1': 7,
#   'po 9.2': 8,
#   'po 9.3': 7,
#   'po 9.4': 7,
#   'po 9.5': 7,
#   'po 9.6': 6,
#   'po 9.7': 7,
#   'po 9.8': 7,
#   'po 9.9': 6,
#   'positive': 719},
#  'R7SEEBB': {'negative': 7},
#  'R94HYZB': {'>1000': 13},
#  'RAJ8P8U': {'bm°á°úâüá¶': 6, '°ñ¼öæçµ¶°á°ú âüá¶': 4},
#  'REGV6TM': {'negative': 13},
#  'RPXTTJW': {'negative': 7},
#  'RQZCRFM': {'equivocal': 6, 'negative': 29, 'positive': 4},
#  'RV2QVYX': {'negative': 9},
#  'RXQ7L9Y': {'negative': 6},
#  'S33DUEP': {'0.02(neg)': 2, '0.03(neg)': 3, '0.04(neg)': 2, '0.05(neg)': 1},
#  'S389P7U': {'negative': 9},
#  'S56V7LL': {'negative': 763, 'positive': 7},
#  'S95NQPV': {'negative': 1},
#  'SAJDGSX': {'negative': 1,
#   'non-rea(c)': 1,
#   'non-react': 3733,
#   'non-reactive': 1714,
#   'non-reactive(0.01)': 6,
#   'reactive': 14,
#   'w-react': 22,
#   'w-reactive': 6,
#   'weakly-reactive': 8},
#  'SHZ8LMX': {'negative': 9},
#  'SJ2RE55': {'negative': 18},
#  'SL7KALX': {'negative': 19},
#  'SU1R46S': {'equivocal': 7, 'negative': 8, 'positive': 26},
#  'SZ3R15A': {'equivocal': 2, 'negative': 69, 'positive': 1},
#  'SZS0MU7': {'negative': 7},
#  'T20DTD7': {'negative': 1, 'º°áöâüá¶': 1},
#  'T24L839': {'negative': 51},
#  'T3OJSS7': {'negative': 1},
#  'T9Q8CEN': {'negative': 15},
#  'TI37KI3': {'negative': 8},
#  'TOQ0V8H': {'neg(0mm)': 25, 'neg(7mm)': 1, 'neg(8mm)': 1},
#  'TR29VHJ': {'negative': 9},
#  'TU19VKD': {'negative': 9},
#  'TUUBLPA': {'negative': 154},
#  'TX0XT07': {'negative': 9},
#  'TXYP6SV': {'negative': 1},
#  'U23G5CX': {'neg   -': 7,
#   'neg  -': 41611,
#   'neg -': 16,
#   'pos   +': 5,
#   'pos  +': 1316,
#   'pos +': 1,
#   'posi +': 1},
#  'UA6XH71': {'negative': 12},
#  'UDR4IL7': {'negative': 19},
#  'UIA1B6N': {'negative': 9},
#  'UNWB0FO': {'+': 66,
#   '++': 28,
#   '+++': 22,
#   '25   tr': 224,
#   '25  tr': 2,
#   '25 tr': 2,
#   'neg': 1,
#   'neg  -': 376,
#   'neg -': 5},
#  'UPICCF2': {'0.00(0)': 2, '0.01(0)': 1, '<0.35(0)': 2},
#  'UPMR3QD': {'negative': 9},
#  'UTC0QU4': {'negative': 7},
#  'UZO4HWX': {'<4': 2, 'negative': 3, 'positive': 59},
#  'V0MHH3Q': {'negative': 19},
#  'V554894': {'0.01(neg)': 3,
#   '0.02(neg)': 6,
#   '0.03(neg)': 5,
#   '0.04(neg)': 3,
#   '0.05(neg)': 2,
#   '0.06(neg)': 1,
#   '0.07(neg)': 1,
#   '101(pos)': 2,
#   'borderline': 6,
#   'negative': 86,
#   'positive': 65},
#  'VASPDMI': {'negative': 7},
#  'VJNLF45': {'+': 981,
#   '++': 838,
#   '+++': 493,
#   '++++': 627,
#   '50   tr': 974,
#   '50  tr': 150,
#   'neg  -': 3378,
#   'norm  -': 5645,
#   'norm -': 29865},
#  'VL1LQLQ': {'negative': 1470,
#   'pos(1.01)': 1,
#   'pos(1.02)': 1,
#   'pos(1.03)': 1,
#   'pos(1.04)': 1,
#   'pos(1.05)': 1,
#   'pos(1.06)': 1,
#   'pos(1.07)': 1,
#   'pos(1.08)': 1,
#   'pos(1.09)': 1,
#   'pos(1.10)': 1,
#   'pos(1.11)': 1,
#   'pos(1.12)': 1,
#   'pos(1.13)': 1,
#   'pos(1.14)': 1,
#   'pos(1.15)': 1,
#   'pos(1.16)': 1,
#   'pos(1.17)': 1,
#   'pos(1.18)': 1,
#   'pos(1.19)': 1,
#   'pos(1.20)': 1,
#   'pos(1.21)': 1,
#   'pos(1.22)': 1,
#   'pos(1.23)': 1,
#   'pos(1.24)': 1,
#   'pos(1.25)': 1,
#   'pos(1.26)': 1,
#   'pos(1.27)': 1,
#   'pos(1.28)': 1,
#   'pos(1.29)': 1,
#   'pos(1.30)': 1,
#   'pos(1.31)': 1,
#   'pos(1.32)': 1,
#   'pos(1.33)': 1,
#   'pos(1.34)': 1,
#   'pos(1.35)': 1,
#   'pos(1.37)': 1,
#   'pos(1.39)': 1,
#   'pos(1.40)': 1,
#   'pos(1.41)': 1,
#   'pos(1.43)': 1,
#   'pos(1.45)': 1,
#   'pos(1.47)': 1,
#   'pos(1.48)': 1,
#   'pos(1.50)': 1,
#   'pos(1.52)': 1,
#   'pos(1.55)': 1,
#   'pos(1.58)': 1,
#   'pos(1.68)': 1,
#   'pos(1.70)': 1,
#   'pos(>1000)': 1,
#   'positive': 3},
#  'VMCVSI3': {'negative': 19},
#  'VPOZU8E': {'negative': 7},
#  'VS1BI7F': {'negative': 6},
#  'VUSJGR4': {'negative': 19},
#  'W1C21KN': {'negative': 7},
#  'W1P01IO': {'>1000': 1},
#  'W5F17MO': {'negative': 4},
#  'W7WL2OI': {'negative': 20},
#  'W8TBNO0': {'negative': 2},
#  'WCY1X9L': {'non-reactive(0.0)': 6,
#   'non-reactive(0.1)': 2735,
#   'non-reactive(0.2)': 20,
#   'non-reactive(0.3)': 19,
#   'non-reactive(0.4)': 18,
#   'non-reactive(0.5)': 19,
#   'non-reactive(0.6)': 16,
#   'non-reactive(0.7)': 14,
#   'non-reactive(0.8)': 13,
#   'non-reactive(0.9)': 13,
#   'non-reactive(1.0)': 14,
#   'non-reactive(1.1)': 13,
#   'non-reactive(1.2)': 10,
#   'non-reactive(1.3)': 10,
#   'non-reactive(1.4)': 10,
#   'non-reactive(1.5)': 9,
#   'non-reactive(1.6)': 9,
#   'non-reactive(1.7)': 9,
#   'non-reactive(1.8)': 8,
#   'non-reactive(1.9)': 8,
#   'non-reactive(2.0)': 7,
#   'non-reactive(2.1)': 6,
#   'non-reactive(2.2)': 7,
#   'non-reactive(2.3)': 5,
#   'non-reactive(2.4)': 6,
#   'non-reactive(2.5)': 5,
#   'non-reactive(2.6)': 5,
#   'non-reactive(2.7)': 5,
#   'non-reactive(2.8)': 5,
#   'non-reactive(2.9)': 4,
#   'non-reactive(3.0)': 4,
#   'non-reactive(3.1)': 4,
#   'non-reactive(3.2)': 4,
#   'non-reactive(3.3)': 3,
#   'non-reactive(3.4)': 4,
#   'non-reactive(3.5)': 3,
#   'non-reactive(3.6)': 3,
#   'non-reactive(3.7)': 2,
#   'non-reactive(3.8)': 3,
#   'non-reactive(3.9)': 3,
#   'non-reactive(4.0)': 2,
#   'non-reactive(4.1)': 2,
#   'non-reactive(4.2)': 2,
#   'non-reactive(4.3)': 1,
#   'non-reactive(4.4)': 2,
#   'non-reactive(4.5)': 2,
#   'non-reactive(4.6)': 2,
#   'non-reactive(4.7)': 1,
#   'non-reactive(4.8)': 1,
#   'non-reactive(4.9)': 1,
#   'non-reactive(5.0)': 2,
#   'non-reactive(5.1)': 1,
#   'non-reactive(5.2)': 1,
#   'non-reactive(5.3)': 1,
#   'non-reactive(5.4)': 1,
#   'non-reactive(5.5)': 2,
#   'non-reactive(5.6)': 1,
#   'non-reactive(5.7)': 1,
#   'non-reactive(5.8)': 1,
#   'non-reactive(6.0)': 1,
#   'non-reactive(6.2)': 1,
#   'non-reactive(9.5)': 2},
#  'WFJ73DN': {'negative': 5},
#  'WNH968Y': {'negative': 8},
#  'WPQK25D': {'negative': 19},
#  'WYP2EN8': {'low pos': 1,
#   'low-posi': 1,
#   'negative': 33,
#   'pos(500.0)': 7,
#   'positive': 17},
#  'X0GY1OH': {'neg': 1},
#  'X7QG4TT': {'negative': 19},
#  'X83YLK5': {'negative': 7},
#  'X8RWBK5': {'negative': 7},
#  'X9PRNEY': {'negative': 3},
#  'XE2IL6S': {'negative': 5},
#  'XFFFUQN': {'negative': 9},
#  'XHALANV': {'negative': 10},
#  'XK14TFL': {'clear': 41435, 'cloudy': 1530, 'hazy': 1},
#  'XNKCTZX': {'neg': 66},
#  'XPBFOJZ': {'positive': 2},
#  'XSG39BD': {'negative': 6825, 'positive': 125},
#  'XVI8LW8': {'negative': 5},
#  'XY4O1KF': {'negative': 1},
#  'XYT0LZG': {'negative': 10388, 'positive': 2},
#  'XZQQI5H': {'negative': 10},
#  'Y263DPW': {'negative': 5},
#  'Y2RU44A': {'negative': 19},
#  'Y55FYS9': {'negative': 6, 'º°áöâüá¶': 1},
#  'Y6IN4A5': {'grayzone': 2,
#   'neg(0.03)': 1,
#   'neg(0.04)': 3,
#   'neg(0.05)': 4,
#   'neg(0.06)': 4,
#   'neg(0.07)': 3,
#   'neg(0.08)': 2,
#   'neg(0.09)': 2,
#   'neg(0.10)': 2,
#   'neg(0.11)': 1,
#   'neg(0.12)': 1,
#   'neg(0.13)': 1,
#   'neg(0.14)': 1,
#   'neg(0.15)': 1,
#   'negative': 127,
#   'positive': 1},
#  'Y6KTN21': {'neg': 4},
#  'Y90GJWL': {'>1000': 1},
#  'YF9RC0G': {'negative': 7},
#  'YJUCNKN': {'negative': 3},
#  'YNHP00X': {'negative': 7},
#  'YWIURH9': {'amber': 5105,
#   'brown': 426,
#   'colorless': 1,
#   'green': 1,
#   'orange': 119,
#   'other': 9,
#   'red': 42,
#   'reddish': 126,
#   'straw': 29834,
#   'yellow': 7293},
#  'YXFMOO4': {'negative': 12},
#  'Z79XHA3': {'negative': 6},
#  'Z949FI0': {'negative': 19},
#  'ZAAT94X': {'0.02(0)': 1, '0.03(0)': 1, '<0.35(0)': 2},
#  'ZEIIY5D': {'>20.00': 7, 'negative': 9, 'positive': 5},
#  'ZF1OD7Y': {'+': 29,
#   '++': 8,
#   '+++': 2,
#   '1    tr': 42,
#   'norm': 3,
#   'norm  -': 2,
#   'norm -': 644},
#  'ZFHJOBU': {'negative': 5},
#  'ZFJ8K8N': {'negative': 148,
#   'positive(> 200.0)': 2,
#   'positive(>100.0)': 4,
#   'positive(>200.0)': 1},
#  'ZIYMV7L': {'negative': 9},
#  'ZJAZ3U4': {'negative': 9},
#  'ZKDS40D': {'positive': 1,
#   'positive(+)': 1,
#   'positive(++)': 1,
#   'w-positive': 1},
#  'ZKOOZIW': {'negative': 9},
#  'ZLRVB94': {'negative': 22},
#  'ZNGHQYP': {'negative': 19},
#  'ZSEN524': {'negative': 18},
#  'ZSSG5RJ': {'negative': 19, 'º°áöâüá¶': 3},
#  'ZTRMXPB': {'negative': 40, 'positive': 1},
#  'ZVYQICG': {'non-reactive(0.00)': 19,
#   'non-reactive(0.01)': 7347,
#   'non-reactive(0.02)': 141,
#   'non-reactive(0.03)': 128,
#   'non-reactive(0.04)': 116,
#   'non-reactive(0.05)': 118,
#   'non-reactive(0.06)': 108,
#   'non-reactive(0.07)': 103,
#   'non-reactive(0.08)': 96,
#   'non-reactive(0.09)': 96,
#   'non-reactive(0.1)': 23,
#   'non-reactive(0.10)': 69,
#   'non-reactive(0.11)': 91,
#   'non-reactive(0.12)': 84,
#   'non-reactive(0.13)': 81,
#   'non-reactive(0.14)': 77,
#   'non-reactive(0.15)': 76,
#   'non-reactive(0.16)': 72,
#   'non-reactive(0.17)': 69,
#   'non-reactive(0.18)': 65,
#   'non-reactive(0.19)': 64,
#   'non-reactive(0.2)': 12,
#   'non-reactive(0.20)': 50,
#   'non-reactive(0.21)': 59,
#   'non-reactive(0.22)': 57,
#   'non-reactive(0.23)': 54,
#   'non-reactive(0.24)': 50,
#   'non-reactive(0.25)': 50,
#   'non-reactive(0.26)': 45,
#   'non-reactive(0.27)': 46,
#   'non-reactive(0.28)': 42,
#   'non-reactive(0.29)': 41,
#   'non-reactive(0.3)': 5,
#   'non-reactive(0.30)': 33,
#   'non-reactive(0.31)': 36,
#   'non-reactive(0.32)': 34,
#   'non-reactive(0.33)': 32,
#   'non-reactive(0.34)': 32,
#   'non-reactive(0.35)': 30,
#   'non-reactive(0.36)': 28,
#   'non-reactive(0.37)': 26,
#   'non-reactive(0.38)': 26,
#   'non-reactive(0.39)': 26,
#   'non-reactive(0.4)': 3,
#   'non-reactive(0.40)': 21,
#   'non-reactive(0.41)': 21,
#   'non-reactive(0.42)': 20,
#   'non-reactive(0.43)': 21,
#   'non-reactive(0.44)': 19,
#   'non-reactive(0.45)': 18,
#   'non-reactive(0.46)': 18,
#   'non-reactive(0.47)': 17,
#   'non-reactive(0.48)': 15,
#   'non-reactive(0.49)': 15,
#   'non-reactive(0.5)': 3,
#   'non-reactive(0.50)': 13,
#   'non-reactive(0.51)': 13,
#   'non-reactive(0.52)': 13,
#   'non-reactive(0.53)': 12,
#   'non-reactive(0.54)': 12,
#   'non-reactive(0.55)': 12,
#   'non-reactive(0.56)': 10,
#   'non-reactive(0.57)': 10,
#   'non-reactive(0.58)': 10,
#   'non-reactive(0.59)': 9,
#   'non-reactive(0.6)': 1,
#   'non-reactive(0.60)': 7,
#   'non-reactive(0.61)': 8,
#   'non-reactive(0.62)': 8,
#   'non-reactive(0.63)': 8,
#   'non-reactive(0.64)': 7,
#   'non-reactive(0.65)': 7,
#   'non-reactive(0.66)': 6,
#   'non-reactive(0.67)': 6,
#   'non-reactive(0.68)': 5,
#   'non-reactive(0.69)': 6,
#   'non-reactive(0.70)': 4,
#   'non-reactive(0.71)': 5,
#   'non-reactive(0.72)': 5,
#   'non-reactive(0.73)': 4,
#   'non-reactive(0.74)': 4,
#   'non-reactive(0.75)': 4,
#   'non-reactive(0.76)': 4,
#   'non-reactive(0.77)': 4,
#   'non-reactive(0.78)': 4,
#   'non-reactive(0.79)': 3,
#   'non-reactive(0.80)': 3,
#   'non-reactive(0.81)': 3,
#   'non-reactive(0.82)': 3,
#   'non-reactive(0.83)': 3,
#   'non-reactive(0.84)': 3,
#   'non-reactive(0.85)': 2,
#   'non-reactive(0.86)': 2,
#   'non-reactive(0.87)': 2,
#   'non-reactive(0.88)': 2,
#   'non-reactive(0.89)': 2,
#   'non-reactive(0.90)': 2,
#   'non-reactive(0.91)': 2,
#   'non-reactive(0.92)': 1,
#   'non-reactive(0.93)': 1,
#   'non-reactive(0.94)': 1,
#   'non-reactive(0.95)': 3,
#   'non-reactive(0.96)': 1,
#   'non-reactive(0.97)': 1,
#   'non-reactive(0.98)': 1,
#   'non-reactive(0.99)': 1},
#  'ZX9HAK0': {'negative': 4}}

# %%
# 2) Laboratory tests Categorization
import re
import collections, re


def get_majors_and_minors(dist_dict, acc_thr=99.5, diff_thr=100, n_thr=9):

    if len(dist_dict) < 5:
        return dist_dict

    total = sum(dist_dict.values())
    
    tmp = {}
    sorted_dist_dict = sorted(dist_dict.items(), key=lambda t: -t[1])
    
    for idx, (k, v) in enumerate(sorted_dist_dict):
        
        if idx==0:
            prev = v
            prev_acc = 0

        acc_ratio = (prev_acc + v) / total * 100
        
        print([idx, k, v, acc_ratio])
        
        #Escape Rules
        if (acc_ratio >= acc_thr): 
            tmp.update({k:v})
            break
            
        if (idx>n_thr): 
            break
            
        tmp.update({k:v})
        prev = v
        prev_acc += v
        
    return tmp


def get_groups(majors,
    rules_A = ['straw','clear','cloudy','yellow','amber','brown','orange'],
    rules_B = ['++', '+++', '++++'],
    rules_C = ['po.*', 'ne.*'],
    rules_D = ['ab','rh+'],
    rules_E = ['rea.*', 'non.*']):

    group_A = [] 
    group_B = [] 
    group_C = [] 
    group_D = []  
    group_E = []  

    message_form = '\n'.join(['Rules_%s: {}' % c for c in 'ABCDE'])
    print(message_form.format(rules_A, rules_B, rules_C,rules_D, rules_E))
    
    def is_group_A(major_dict):
        return sum([1 for k in major_dict.keys() if k in rules_A])
    def is_group_B(major_dict):
        return sum([1 for k in major_dict.keys() if k in rules_B])
    def is_group_C(major_dict):
        return sum([1 for s in major_dict.keys() for r in rules_C if re.findall(r, s)])
    def is_group_D(major_dict):
        return sum([1 for k in major_dict.keys() if k in rules_D])
    def is_group_E(major_dict):
        return sum([1 for s in major_dict.keys() for r in rules_E if re.findall(r,s)])

    for table_cid, major_dict in majors.items():
        
        if is_group_A(major_dict): 
            group_A.append(table_cid)
            
        elif is_group_B(major_dict):
            group_B.append(table_cid)
            
        elif is_group_C(major_dict):
            group_C.append(table_cid)
            
        elif is_group_D(major_dict): 
            group_D.append(table_cid)
            
        elif is_group_E(major_dict):
            group_E.append(table_cid)
            

    merge_group_set = set(group_A + group_B + group_C + group_D + group_E)
    group_others = [table_cid for table_cid in majors.keys() if table_cid not in merge_group_set]
    return [group_A, group_B, group_C, group_D, group_E, group_others]


def get_group_dict(group, regex=lambda x:x):
    
    group_dict = defaultdict(int)
               
    for table_cid in group:
        for k, v in dist_dicts[table_cid].items():
            group_dict[regex(re.sub(r'\s+', ' ', k))] += v
    
    return group_dict


majors = {table_cid:get_majors_and_minors(dist_dict, acc_thr=99.5) 
          for table_cid, dist_dict in dist_dicts.items()}
groups = get_groups(majors)
groups_dict = [get_group_dict(group) for group in groups] 
groups_sample = [group_dict.keys() for group_dict in groups_dict]
# Out:
# [0, 'neg  -', 41611, 96.8666340759364]
# [1, 'pos  +', 1316, 99.9301627208604]
# [0, 'neg  -', 41216, 95.95604497939608]
# [1, '+', 1328, 99.04779642865458]
# [2, '++', 208, 99.53204665564687]
# [0, 'neg  -', 38872, 90.5010243993295]
# [1, '5    tr', 1779, 94.64285714285714]
# [2, '+', 820, 96.55196498416836]
# [3, '++', 581, 97.90463773514621]
# [4, '+++', 442, 98.93369342521885]
# [5, '5  tr', 436, 99.9487800335258]
# [0, 'norm -', 35351, 82.30541780168097]
# [1, 'norm  -', 5272, 94.57987008451492]
# [2, '1    tr', 876, 96.61940350632115]
# [3, '1  tr', 737, 98.33531233265815]
# [4, '+', 505, 99.51107075504645]
# [0, 'neg  -', 34862, 81.16880093131549]
# [1, '25   tr', 3184, 88.58207217694995]
# [2, '+', 1938, 93.0942956926659]
# [3, '++', 1494, 96.57275902211875]
# [4, '+++', 953, 98.79161816065192]
# [5, '25  tr', 503, 99.9627473806752]
# [0, 'neg  -', 34664, 80.71155816336034]
# [1, '+', 4106, 90.27195678494924]
# [2, '++', 2516, 96.13020396758871]
# [3, '+++', 1643, 99.95576045450312]
# [0, 'norm -', 29865, 69.53272333589439]
# [1, 'norm  -', 5645, 82.67560708714582]
# [2, 'neg  -', 3378, 90.54038322739866]
# [3, '+', 981, 92.82438127168169]
# [4, '50   tr', 974, 95.09208167446626]
# [5, '++', 838, 97.0431421852809]
# [6, '++++', 627, 98.50294521664222]
# [7, '+++', 493, 99.65076482503318]
# [0, 'straw', 29834, 69.4524629853804]
# [1, 'yellow', 7293, 86.43030077288388]
# [2, 'amber', 5105, 98.31455442778658]
# [3, 'brown', 426, 99.30626687773537]
# [4, 'reddish', 126, 99.59959027842443]
# [0, 'neg  -', 24207, 56.372697422044205]
# [1, '10   tr', 5370, 68.87822826669151]
# [2, '+', 5110, 80.77827717100207]
# [3, '++++', 2962, 87.67611373745372]
# [4, '++', 2892, 94.41093593535315]
# [5, '+++', 1859, 98.74013180876085]
# [6, '10  tr', 526, 99.96506834959595]
# [0, 'negative', 15777, 99.1765149610259]
# [1, 'pos(11.00)', 105, 99.83656022127232]
# [0, 'negative', 10317, 84.3374478868634]
# [1, 'neg(0.22)', 111, 85.24482955938853]
# [2, 'neg(0.23)', 111, 86.15221123191368]
# [3, 'neg(0.24)', 110, 87.05141829477643]
# [4, 'neg(0.25)', 109, 87.94245074797679]
# [5, 'neg(0.26)', 102, 88.77626093354041]
# [6, 'neg(0.21)', 102, 89.61007111910406]
# [7, 'neg(0.27)', 93, 90.3703098177062]
# [8, 'neg(0.28)', 89, 91.09785007765879]
# [9, 'neg(0.20)', 85, 91.79269189896182]
# [10, 'neg(0.29)', 80, 92.44666067195291]
# [0, 'non-reactive(0.01)', 7347, 71.25400058190282]
# [1, 'non-reactive(0.02)', 141, 72.62147221414024]
# [2, 'non-reactive(0.03)', 128, 73.86286490156144]
# [3, 'non-reactive(0.05)', 118, 75.00727378527786]
# [4, 'non-reactive(0.04)', 116, 76.13228590825332]
# [5, 'non-reactive(0.06)', 108, 77.17971098826496]
# [6, 'non-reactive(0.07)', 103, 78.1786441664242]
# [7, 'non-reactive(0.08)', 96, 79.10968868199011]
# [8, 'non-reactive(0.09)', 96, 80.04073319755601]
# [9, 'non-reactive(0.11)', 91, 80.92328581126952]
# [10, 'non-reactive(0.12)', 84, 81.73794976238969]
# [0, 'a', 5573, 34.18598944914734]
# [1, 'o', 4472, 61.61820635504846]
# [2, 'b', 4416, 88.70690712795975]
# [3, 'ab', 1818, 99.85891301680775]
# [0, 'non-react', 3733, 67.811080835604]
# [1, 'non-reactive', 1714, 98.9464123524069]
# [2, 'w-react', 22, 99.34604904632153]
# [3, 'reactive', 14, 99.60036330608538]
# [0, 'non-reactive(0.1)', 2735, 88.45407503234154]
# [1, 'non-reactive(0.2)', 20, 89.10090556274255]
# [2, 'non-reactive(0.3)', 19, 89.71539456662354]
# [3, 'non-reactive(0.5)', 19, 90.32988357050453]
# [4, 'non-reactive(0.4)', 18, 90.91203104786545]
# [5, 'non-reactive(0.6)', 16, 91.42949547218629]
# [6, 'non-reactive(1.0)', 14, 91.88227684346701]
# [7, 'non-reactive(0.7)', 14, 92.33505821474773]
# [8, 'non-reactive(0.8)', 13, 92.75549805950841]
# [9, 'non-reactive(1.1)', 13, 93.17593790426908]
# [10, 'non-reactive(0.9)', 13, 93.59637774902976]
# [0, 'negative', 2527, 46.90051967334818]
# [1, 'positive', 719, 60.244988864142535]
# [2, 'po 1.1', 55, 61.26577579806979]
# [3, 'po 1.2', 50, 62.19376391982183]
# [4, 'po 1.3', 45, 63.02895322939867]
# [5, 'po 1.4', 41, 63.789903489235336]
# [6, 'po 1.5', 37, 64.47661469933185]
# [7, 'po 1.6', 35, 65.12620638455829]
# [8, 'po 1.7', 32, 65.72011878247959]
# [9, 'po 1.8', 31, 66.29547141796584]
# [10, 'po 1.9', 29, 66.83370452858203]
# [0, 'negative', 1470, 96.52002626395273]
# [1, 'positive', 3, 96.71700590938937]
# [2, 'pos(1.68)', 1, 96.78266579120157]
# [3, 'pos(>1000)', 1, 96.84832567301379]
# [4, 'pos(1.70)', 1, 96.913985554826]
# [5, 'pos(1.58)', 1, 96.97964543663822]
# [6, 'pos(1.55)', 1, 97.04530531845043]
# [7, 'pos(1.52)', 1, 97.11096520026264]
# [8, 'pos(1.50)', 1, 97.17662508207485]
# [9, 'pos(1.48)', 1, 97.24228496388706]
# [10, 'pos(1.47)', 1, 97.30794484569928]
# [0, 'negative', 1424, 25.857998910477576]
# [1, 'positive', 855, 41.38369348102415]
# [2, 'ne 0.5', 151, 44.12565825313238]
# [3, 'po>1000', 144, 46.74051207554022]
# [4, 'ne 1.0', 36, 47.39422553114218]
# [5, 'po 1.2', 29, 47.92082803704376]
# [6, 'po 1.3', 27, 48.41111312874523]
# [7, 'po 1.4', 27, 48.90139822044671]
# [8, 'ne 0.1', 27, 49.391683312148174]
# [9, 'po 1.5', 26, 49.86380969674959]
# [10, 'po 1.1', 25, 50.31777737425095]
# [0, 'neg(2.00)', 1388, 26.925315227934043]
# [1, 'pos(>1000)', 1320, 52.53152279340446]
# [2, 'negative', 1207, 75.94568380213384]
# [3, 'neg(0.01)', 215, 80.11639185257032]
# [4, 'positive', 102, 82.09505334626576]
# [5, 'neg(0.04)', 4, 82.17264791464598]
# [6, 'neg(0.06)', 4, 82.2502424830262]
# [7, 'neg(0.08)', 4, 82.3278370514064]
# [8, 'neg(0.07)', 4, 82.40543161978661]
# [9, 'neg(0.26)', 4, 82.48302618816683]
# [10, 'neg(0.09)', 4, 82.56062075654704]
# [0, 'non-react', 1142, 55.734504636408]
# [1, 'non-reactive', 666, 88.23816495851635]
# [2, 'negative', 152, 95.6564177647633]
# [3, 'reactive', 55, 98.34065397755003]
# [4, 'w-react', 12, 98.92630551488531]
# [5, 'positive', 9, 99.36554416788678]
# [6, 'weakly-reactive', 4, 99.56076134699853]
# [0, 'neg  -', 686, 93.58799454297409]
# [1, 'pos  +', 32, 97.95361527967258]
# [2, 'neg -', 10, 99.31787175989086]
# [3, 'neg', 4, 99.86357435197817]
# [0, 'norm -', 644, 88.21917808219179]
# [1, '1    tr', 42, 93.97260273972603]
# [2, '+', 29, 97.94520547945206]
# [3, '++', 8, 99.04109589041096]
# [4, 'norm', 3, 99.45205479452055]
# [5, '+++', 2, 99.72602739726028]
# [0, 'neg  -', 637, 86.9031377899045]
# [1, '+', 66, 95.90723055934515]
# [2, 'neg -', 10, 97.27148703956344]
# [3, '++', 9, 98.4993178717599]
# [4, '+++', 7, 99.45429740791269]
# [5, 'neg', 3, 99.86357435197817]
# [0, 'negative', 627, 36.559766763848394]
# [1, 'positive', 484, 64.78134110787171]
# [2, 'neg(0.08)', 72, 68.9795918367347]
# [3, 'neg(0.09)', 67, 72.8862973760933]
# [4, 'neg(0.07)', 66, 76.73469387755102]
# [5, 'neg(0.10)', 52, 79.76676384839651]
# [6, 'neg(0.06)', 44, 82.332361516035]
# [7, 'neg(0.11)', 39, 84.60641399416909]
# [8, 'neg(0.12)', 29, 86.29737609329446]
# [9, 'neg(0.05)', 23, 87.63848396501459]
# [10, 'neg(0.13)', 21, 88.86297376093295]
# [0, 'neg  -', 614, 84.22496570644718]
# [1, '5    tr', 31, 88.47736625514403]
# [2, '++', 29, 92.45541838134432]
# [3, '+', 22, 95.47325102880659]
# [4, '+++', 20, 98.21673525377228]
# [5, 'neg -', 9, 99.45130315500685]
# [6, 'neg', 3, 99.86282578875172]
# [0, 'norm -', 597, 82.11829436038515]
# [1, '+++', 40, 87.62035763411279]
# [2, '50   tr', 38, 92.84731774415405]
# [3, '+', 34, 97.52407152682255]
# [4, '++', 15, 99.58734525447042]
# [0, 'negative', 495, 65.04599211563732]
# [1, 'positive', 167, 86.99080157687253]
# [2, 'pos(>120)', 84, 98.02890932982918]
# [3, 'pos(8.00)', 13, 99.73718791064388]
# [0, 'neg  -', 465, 63.873626373626365]
# [1, '+', 155, 85.16483516483517]
# [2, '++', 55, 92.71978021978022]
# [3, '+++', 45, 98.9010989010989]
# [4, 'neg -', 6, 99.72527472527473]
# [0, 'neg  -', 376, 51.790633608815426]
# [1, '25   tr', 224, 82.64462809917356]
# [2, '+', 66, 91.73553719008265]
# [3, '++', 28, 95.59228650137742]
# [4, '+++', 22, 98.62258953168043]
# [5, 'neg -', 5, 99.31129476584022]
# [6, '25  tr', 2, 99.58677685950413]
# [0, 'neg  -', 289, 39.75240715268226]
# [1, '++++', 127, 57.22145804676754]
# [2, '10   tr', 103, 71.38927097661623]
# [3, '+', 93, 84.181568088033]
# [4, '++', 56, 91.88445667125173]
# [5, '+++', 51, 98.89958734525447]
# [6, 'neg -', 4, 99.44979367262724]
# [7, '10 tr', 2, 99.72489683631362]
# [0, 'negative', 278, 16.498516320474778]
# [1, 'pos(0.002)', 132, 24.33234421364985]
# [2, 'pos(0.004)', 98, 30.148367952522253]
# [3, 'pos(0.02)', 91, 35.54896142433234]
# [4, 'pos(0.003)', 90, 40.89020771513353]
# [5, 'pos(0.01)', 70, 45.04451038575667]
# [6, 'pos(0.03)', 43, 47.596439169139465]
# [7, 'pos(0.005)', 34, 49.61424332344214]
# [8, 'pos(0.001)', 14, 50.445103857566764]
# [9, 'pos(0.04)', 14, 51.275964391691396]
# [10, 'pos(0.006)', 14, 52.10682492581602]
# [0, 'negative', 244, 71.76470588235294]
# [1, 'positive', 79, 95.0]
# [2, 'po 1.1', 3, 95.88235294117648]
# [3, 'po 1.3', 2, 96.47058823529412]
# [4, 'po 1.2', 2, 97.05882352941177]
# [5, 'po 2.4', 1, 97.35294117647058]
# [6, 'po 2.0', 1, 97.6470588235294]
# [7, 'po 1.9', 1, 97.94117647058823]
# [8, 'po 1.8', 1, 98.23529411764706]
# [9, 'po 1.7', 1, 98.52941176470588]
# [10, 'po 1.6', 1, 98.82352941176471]
# [0, 'negative', 221, 74.16107382550335]
# [1, 'positive', 68, 96.97986577181209]
# [2, 'po 1.2', 2, 97.6510067114094]
# [3, 'po 1.0', 1, 97.98657718120806]
# [4, 'po 1.1', 1, 98.3221476510067]
# [5, 'po 1.3', 1, 98.65771812080537]
# [6, 'po 1.4', 1, 98.99328859060402]
# [7, 'po 1.5', 1, 99.32885906040269]
# [8, 'po 1.6', 1, 99.66442953020133]
# [0, 'negative', 220, 43.91217564870259]
# [1, 'positive(1:40)', 86, 61.07784431137725]
# [2, 'positive(1:80)', 65, 74.05189620758483]
# [3, 'positive(1:320)', 46, 83.23353293413174]
# [4, 'positive(1:160)', 45, 92.21556886227546]
# [5, 'pos(1:40)', 9, 94.01197604790418]
# [6, 'pos(1:80)', 6, 95.20958083832335]
# [7, 'positive(1:640)', 5, 96.20758483033931]
# [8, 'pos(1:320)', 4, 97.0059880239521]
# [9, 'pos(1:160)', 4, 97.80439121756487]
# [10, 'pos(>1:320', 3, 98.40319361277446]
# [0, 'negative', 158, 61.71875]
# [1, '0.02(neg)', 27, 72.265625]
# [2, '0.03(neg)', 17, 78.90625]
# [3, '0.01(neg)', 16, 85.15625]
# [4, 'positive', 10, 89.0625]
# [5, '0.04(neg)', 8, 92.1875]
# [6, 'borderline', 4, 93.75]
# [7, '0.05(neg)', 4, 95.3125]
# [8, '0.00(neg)', 4, 96.875]
# [9, '0.07(neg)', 2, 97.65625]
# [10, '0.06(neg)', 2, 98.4375]
# [0, 'negative', 156, 61.1764705882353]
# [1, '0.02(neg)', 23, 70.19607843137254]
# [2, '0.03(neg)', 21, 78.43137254901961]
# [3, '0.04(neg)', 16, 84.70588235294117]
# [4, 'positive', 13, 89.80392156862746]
# [5, '0.05(neg)', 8, 92.94117647058823]
# [6, '0.01(neg)', 5, 94.90196078431372]
# [7, '0.06(neg)', 4, 96.47058823529412]
# [8, 'borderline', 3, 97.6470588235294]
# [9, '0.07(neg)', 2, 98.4313725490196]
# [10, '0.10(neg)', 1, 98.82352941176471]
# [0, 'non-react', 147, 60.99585062240664]
# [1, 'non-reactive', 80, 94.1908713692946]
# [2, 'non-rea(c)', 4, 95.850622406639]
# [3, 'w-rea(1:1)', 3, 97.0954356846473]
# [4, 'react(1:1)', 2, 97.9253112033195]
# [5, 'non-reactive(csf)', 2, 98.7551867219917]
# [6, 'weakly-reactive(1:1)', 1, 99.1701244813278]
# [7, 'w-react', 1, 99.5850622406639]
# [0, 'negative', 127, 81.41025641025641]
# [1, 'neg(0.05)', 4, 83.97435897435898]
# [2, 'neg(0.06)', 4, 86.53846153846155]
# [3, 'neg(0.04)', 3, 88.46153846153845]
# [4, 'neg(0.07)', 3, 90.38461538461539]
# [5, 'grayzone', 2, 91.66666666666666]
# [6, 'neg(0.08)', 2, 92.94871794871796]
# [7, 'neg(0.09)', 2, 94.23076923076923]
# [8, 'neg(0.10)', 2, 95.51282051282051]
# [9, 'neg(0.11)', 1, 96.15384615384616]
# [10, 'neg(0.03)', 1, 96.7948717948718]
# [0, 'negative', 86, 47.77777777777778]
# [1, 'positive', 65, 83.88888888888889]
# [2, 'borderline', 6, 87.22222222222223]
# [3, '0.02(neg)', 6, 90.55555555555556]
# [4, '0.03(neg)', 5, 93.33333333333333]
# [5, '0.01(neg)', 3, 95.0]
# [6, '0.04(neg)', 3, 96.66666666666667]
# [7, '0.05(neg)', 2, 97.77777777777777]
# [8, '101(pos)', 2, 98.88888888888889]
# [9, '0.07(neg)', 1, 99.44444444444444]
# [10, '0.06(neg)', 1, 100.0]
# [0, 'negative', 85, 93.4065934065934]
# [1, 'po 1.0', 2, 95.6043956043956]
# [2, 'po 2.7', 1, 96.7032967032967]
# [3, 'po 2.4', 1, 97.8021978021978]
# [4, 'po 2.1', 1, 98.9010989010989]
# [5, 'po 2.0', 1, 100.0]
# [0, 'negative', 82, 84.5360824742268]
# [1, 'positive', 4, 88.65979381443299]
# [2, '0.02(neg)', 4, 92.78350515463917]
# [3, '0.03(neg)', 3, 95.87628865979381]
# [4, '0.01(neg)', 2, 97.9381443298969]
# [5, '0.04(neg)', 1, 98.96907216494846]
# [6, 'borderline', 1, 100.0]
# [0, 'negative', 72, 82.75862068965517]
# [1, 'positive', 3, 86.20689655172413]
# [2, 'po 1.1', 1, 87.35632183908046]
# [3, 'po 1.2', 1, 88.50574712643679]
# [4, 'po 1.3', 1, 89.65517241379311]
# [5, 'po 1.4', 1, 90.80459770114942]
# [6, 'po 1.5', 1, 91.95402298850574]
# [7, 'po 1.6', 1, 93.10344827586206]
# [8, 'po 1.7', 1, 94.25287356321839]
# [9, 'po 1.8', 1, 95.40229885057471]
# [10, 'po 1.9', 1, 96.55172413793103]
# [0, 'negative', 44, 86.27450980392157]
# [1, 'positive', 3, 92.15686274509804]
# [2, 'w-positive', 2, 96.07843137254902]
# [3, 'positive(+)', 1, 98.0392156862745]
# [4, 'positive(++)', 1, 100.0]
# [0, 'negative', 33, 55.932203389830505]
# [1, 'positive', 17, 84.7457627118644]
# [2, 'pos(500.0)', 7, 96.61016949152543]
# [3, 'low-posi', 1, 98.30508474576271]
# [4, 'low pos', 1, 100.0]
# [0, 'negative', 8, 47.05882352941176]
# [1, 'neg', 4, 70.58823529411765]
# [2, 'neg -', 2, 82.35294117647058]
# [3, 'positive', 2, 94.11764705882352]
# [4, 'pos', 1, 100.0]
# [0, '0.01(neg)', 4, 36.36363636363637]
# [1, '0.02(neg)', 3, 63.63636363636363]
# [2, '0.03(neg)', 2, 81.81818181818183]
# [3, '0.04(neg)', 1, 90.9090909090909]
# [4, '0.00(neg)', 1, 100.0]
# Rules_A: ['straw', 'clear', 'cloudy', 'yellow', 'amber', 'brown', 'orange']
# Rules_B: ['++', '+++', '++++']
# Rules_C: ['po.*', 'ne.*']
# Rules_D: ['ab', 'rh+']
# Rules_E: ['rea.*', 'non.*']

# %%
from itertools import chain
import pandas as pd
from scipy import spatial


class Mapper():
    def __init__(self, samples, ref_list):
        self.samples = samples
        self.ref_list = ref_list
        
    def create_feature_matrix(self, samples1, samples2):
        def _create_feature_matrix(samples, refs):
            #refs는 feature list
            result = []
            row_idx = []
            for r_idx, ng_str in enumerate(samples):
                result.append([0]*len(refs))
                for ng_char in ng_str:
                    result[r_idx][refs.index(ng_char)] += 1
            return result

        samples1 = [s.lower() for s in samples1]
        samples2 = [s.lower() for s in samples2]
        refs = list(set(chain.from_iterable(samples1+samples2)))
        matrix1 = _create_feature_matrix(samples1, refs)
        matrix2 = _create_feature_matrix(samples2, refs)
        return matrix1, matrix2
    
    def assign_to_ref(self, sample_vectors, ref_vectors, sample_list, ref_list):
        def cosine_similarity_matrix(matrix1, matrix2):

            distance = []
            for s_idx, sample in enumerate(matrix1):
                distance.append([])
                for ref in matrix2:
                    distance[s_idx].append(
                        round(1-spatial.distance.cosine(sample, ref),2)
                    )
            return distance
        
        def lp_dist_matrix(matrix1, matrix2):
            distance = []
            for s_idx, sample in enumerate(matrix1):
                distance.append([])
                for ref in matrix2:
                    distance[s_idx].append(
                        round(spatial.distance.euclidean(sample, ref),2)
                    )
            return distance
        
        def levenshtein_measure(sample_list, ref_list):
            def levenshtein(s1, s2):
            # based on Wikipedia/Levenshtein_distance
                if len(s1) < len(s2):
                    return levenshtein(s2, s1)

                if len(s2) == 0:
                    return len(s1)
    
                previous_row = range(len(s2) + 1)
                for i, c1 in enumerate(s1):
                    current_row = [i + 1]
                    for j, c2 in enumerate(s2):
                        insertions = previous_row[j + 1] + 1
                        deletions = current_row[j] + 1
                        substitutions = previous_row[j] + (c1 != c2)
                        current_row.append(min(insertions, deletions, substitutions))
                    previous_row = current_row
    
                return previous_row[-1]
    
            distance = []
            for s_idx, sample in enumerate(sample_list):
                distance.append([])
                for ref in ref_list:
                    distance[s_idx].append(levenshtein(sample, ref))
            return distance

        
        sample_list = list(sample_list)

        cos_scores = cosine_similarity_matrix(sample_vectors, ref_vectors)
        lev_scores  = levenshtein_measure(sample_list, ref_list)
        lp_dist_scores = lp_dist_matrix(sample_vectors, ref_vectors)
        
        result = []
        outlier = []
        for s_idx, sample in enumerate(sample_vectors):
            max_cos_score = max(cos_scores[s_idx])
            max_cos_idx = cos_scores[s_idx].index(max_cos_score)
            max_cos_cnt = cos_scores[s_idx].count(max_cos_score)
            min_lp_dist_score = min(lp_dist_scores[s_idx])
            min_lp_dist_idx = lp_dist_scores[s_idx].index(min_lp_dist_score)
            min_lp_dist_cnt = lp_dist_scores[s_idx].count(min_lp_dist_score)
            min_lev_score = min(lev_scores[s_idx])
            min_lev_idx = lev_scores[s_idx].index(min_lev_score)
            
            if max_cos_cnt == len(cos_scores[s_idx]):
                outlier.append(
                    [sample_list[s_idx],
                     ref_list[max_cos_idx],
                     cos_scores[s_idx]]
                )
            else:
                result.append(
                    [sample_list[s_idx],
                     ref_list[max_cos_idx],
                     cos_scores[s_idx],
                     ref_list[min_lp_dist_idx],
                     lp_dist_scores[s_idx],
                     ref_list[min_lev_idx],
                     lev_scores[s_idx],
                     'cosine' if max_cos_cnt <= 1 else 'Eucl',
                     ref_list[max_cos_idx] if max_cos_cnt <= 1 else ref_list[min_lp_dist_idx]]
                )

        return result, outlier
    
    def get_report_df(self, results):

        report_df = pd.DataFrame(
            results,
            columns=[
                'Data',
                'cos_word',
                'cos_score',
                'euc_word',
                'euc_score',
                'lev_word',
                'lev_score',
                'Measure',
                'Final'
            ]
        )
        report_df = report_df[['Data','Final']]
        return report_df
    
    def analyze(self):
        self._sample_vectors, self._ref_vectors = self.create_feature_matrix(
            self.samples, self.ref_list)
        
        self._cluster_results, self._outlier = self.assign_to_ref(
            self._sample_vectors, self._ref_vectors, self.samples, self.ref_list)
        
        self.report_df= self.get_report_df(self._cluster_results)

        
ref_list_A = ['straw', 'amber', 'brown', 'green', 'yellow', 'orange', 'black','blue', 'red', 'other', 'clear', 'cloudy', 'hazy', 'turbid', 'bloody']
ref_list_B = ['neg', 'trace', '+', '++', '+++', '++++']
ref_list_C = ['posi', 'neg-','weak-pos']
ref_list_D = ['a','b','c','ab','cisab','rh+','rh-','partiald','weakd','variantd'] 
ref_list_E = ['reac', 'non-reac','weak-reac']

groups_agents = [
    Mapper(sample, ref_list) for sample, ref_list in zip(
        groups_sample[:-1],
        [ref_list_A, ref_list_B, ref_list_C,ref_list_D,ref_list_E]
    )
]

for agent in groups_agents:
    agent.analyze()

# %%
# 4) Result table
groups_agents[0].report_df
# Out:
#          Data   Final
# 0       clear   clear
# 1      cloudy  cloudy
# 2        hazy    hazy
# 3       straw   straw
# 4      yellow  yellow
# 5       amber   amber
# 6       brown   brown
# 7     reddish     red
# 8      orange  orange
# 9         red     red
# 10      other   other
# 11      green   green
# 12  colorless  yellow

# %%
groups_agents[1].report_df
# Out:
#       Data  Final
# 0    neg -    neg
# 1        +      +
# 2       ++     ++
# 3      +++    +++
# 4     5 tr  trace
# 5    25 tr  trace
# 6   norm -    neg
# 7    50 tr  trace
# 8     ++++   ++++
# 9    10 tr  trace
# 10    1 tr  trace
# 11    norm    neg
# 12     neg    neg

# %%
groups_agents[2].report_df
# Out:
#                    Data     Final
# 0                 neg -      neg-
# 1                 pos +      posi
# 2                posi +      posi
# 3              negative      neg-
# 4            pos(11.00)      posi
# 5              pos(6.6)      posi
# 6              pos(6.9)      posi
# 7              pos(7.0)      posi
# 8              pos(7.2)      posi
# 9              pos(7.1)      posi
# 10             pos(6.8)      posi
# 11             pos(6.0)      posi
# 12             pos(6.1)      posi
# 13             pos(6.2)      posi
# 14             pos(6.3)      posi
# 15             pos(6.4)      posi
# 16             pos(6.5)      posi
# 17             pos(6.7)      posi
# 18             pos(7.3)      posi
# 19             pos(7.4)      posi
# 20             pos(7.5)      posi
# 21             pos(7.6)      posi
# 22             pos(7.7)      posi
# 23             pos(7.8)      posi
# 24             pos(7.9)      posi
# 25             pos(8.0)      posi
# 26             positive      posi
# 27            neg(0.22)      neg-
# 28            neg(0.23)      neg-
# 29            neg(0.24)      neg-
# ...                 ...       ...
# 2006          0.11(neg)      neg-
# 2007          0.08(neg)      neg-
# 2008          0.09(neg)      neg-
# 2009          0.10(neg)      neg-
# 2010   positive(>100.0)      posi
# 2011  positive(> 200.0)      posi
# 2012   positive(>200.0)      posi
# 2013           grayzone      neg-
# 2014           101(pos)      posi
# 2015          equivocal  weak-pos
# 2016         pos(p-type      posi
# 2017          neg(1:80)      neg-
# 2018         neg(1:160)      neg-
# 2019         w-positive      posi
# 2020        positive(+)      posi
# 2021       positive(++)      posi
# 2022         pos(500.0)      posi
# 2023           low-posi      posi
# 2024            low pos      posi
# 2025           neg(0mm)      neg-
# 2026           neg(8mm)      neg-
# 2027           neg(7mm)      neg-
# 2028     positive(>100)      posi
# 2029          pos(1:32)      posi
# 2030          pos(1:64)      posi
# 2031             pos(4)      posi
# 2032             pos(3)      posi
# 2033                pos      posi
# 2034  positive (>300.0)      posi
# 2035     negative(<1.0)      neg-
#
# [2036 rows x 2 columns]

# %%
groups_agents[3].report_df
# Out:
#    Data Final
# 0     a     a
# 1     b     b
# 2    ab    ab
# 3   bmt     b
# 4   a2b    ab
# 5  a2b3    ab
# 6  a1b3    ab
# 7    a3     a
# 8    b3     b

# %%
groups_agents[4].report_df
# Out:
#                      Data      Final
# 0      non-reactive(0.01)   non-reac
# 1      non-reactive(0.02)   non-reac
# 2      non-reactive(0.03)   non-reac
# 3      non-reactive(0.05)   non-reac
# 4      non-reactive(0.04)   non-reac
# 5      non-reactive(0.06)   non-reac
# 6      non-reactive(0.07)   non-reac
# 7      non-reactive(0.08)   non-reac
# 8      non-reactive(0.09)   non-reac
# 9      non-reactive(0.11)   non-reac
# 10     non-reactive(0.12)   non-reac
# 11     non-reactive(0.13)   non-reac
# 12     non-reactive(0.14)   non-reac
# 13     non-reactive(0.15)   non-reac
# 14     non-reactive(0.16)   non-reac
# 15     non-reactive(0.10)   non-reac
# 16     non-reactive(0.17)   non-reac
# 17     non-reactive(0.18)   non-reac
# 18     non-reactive(0.19)   non-reac
# 19     non-reactive(0.21)   non-reac
# 20     non-reactive(0.22)   non-reac
# 21     non-reactive(0.23)   non-reac
# 22     non-reactive(0.20)   non-reac
# 23     non-reactive(0.24)   non-reac
# 24     non-reactive(0.25)   non-reac
# 25     non-reactive(0.27)   non-reac
# 26     non-reactive(0.26)   non-reac
# 27     non-reactive(0.28)   non-reac
# 28     non-reactive(0.29)   non-reac
# 29     non-reactive(0.31)   non-reac
# ..                    ...        ...
# 145     non-reactive(3.8)   non-reac
# 146     non-reactive(3.9)   non-reac
# 147     non-reactive(9.5)   non-reac
# 148     non-reactive(5.5)   non-reac
# 149     non-reactive(5.0)   non-reac
# 150     non-reactive(3.7)   non-reac
# 151     non-reactive(4.0)   non-reac
# 152     non-reactive(4.1)   non-reac
# 153     non-reactive(4.2)   non-reac
# 154     non-reactive(4.4)   non-reac
# 155     non-reactive(4.5)   non-reac
# 156     non-reactive(4.6)   non-reac
# 157     non-reactive(4.3)   non-reac
# 158     non-reactive(4.7)   non-reac
# 159     non-reactive(6.2)   non-reac
# 160     non-reactive(6.0)   non-reac
# 161     non-reactive(4.8)   non-reac
# 162     non-reactive(5.8)   non-reac
# 163     non-reactive(5.7)   non-reac
# 164     non-reactive(5.6)   non-reac
# 165     non-reactive(5.4)   non-reac
# 166     non-reactive(5.3)   non-reac
# 167     non-reactive(5.2)   non-reac
# 168     non-reactive(5.1)   non-reac
# 169     non-reactive(4.9)   non-reac
# 170            w-rea(1:1)  weak-reac
# 171            react(1:1)       reac
# 172     non-reactive(csf)   non-reac
# 173  weakly-reactive(1:1)  weak-reac
# 174            react(1:2)       reac
#
# [175 rows x 2 columns]
